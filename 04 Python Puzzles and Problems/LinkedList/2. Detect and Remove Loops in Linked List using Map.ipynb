# %% [markdown]
# ### Detect Cycle in a Linked List using Map
#
# Detect Cycle in a Linked List using Map
#
# Example
# Input: 20->4->54->6->NULL
# Output: No loop is detected.
# Explanation:
# While traversing the linked list, we reach the end of the linked list. Therefore, no loop is present in the linked list
#
#
# Input: 20->4->5->10->20
# Output: Loop detected.
# Explanation:
# While traversing the linked list, reaching the node with value 10, it is linked with the head node, which depicts a loop in the linked list. Therefore, a loop is present in the link
#
# Approach:
#
# 1. Create a map that will store the visited node in the linked list.
# 2. Traverse the linked list and do the following:
#     * Check whether the current node is present on the map or not.
#     * If the current node is not present in the map then, insert the current node into the map.
#     * If the Node is present in the map, the loop in a linked list is detected.
# 3. If we reach the Null Node while traversing the linked list then, the given linked list has no loop present in it.ed list.  in it.

# %% [markdown]
# References:
# https://www.geeksforgeeks.org/detect-cycle-in-a-linked-list-using-map/?ref=next_article

# %%
class Node:
    def __init__(self, x):
        self.value = x 
        self.next = None 

def newNode(d):
    temp = Node(d)
    return temp

# declare a map to store the visited node 
visited = {}
flag = False 

def checkForCycle(head):
    global vis, flag
    if head == None:
        flag = False 
        return 

    if head not in visited:
        vis[head] = True
        check(head.next)
# Out:
#   Cell In[1], line 15
#
#     ^
# SyntaxError: incomplete input
