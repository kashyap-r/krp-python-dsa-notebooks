# %%
# String to Char
#  Soln 1 

str = 'Kashyap Raj!'
list = []
for char in str:
    list.append(char)

list
# Out:
# ['K', 'a', 's', 'h', 'y', 'a', 'p', ' ', 'R', 'a', 'j', '!']

# %%
# Soln 2
str = 'Kashyap Raj!'
list = []
for i in range(0, len(str)):
    list.append(str[i])

list
# Out:
# ['K', 'a', 's', 'h', 'y', 'a', 'p', ' ', 'R', 'a', 'j', '!']

# %%
# Char list  to string 
char = ['K', 'a', 's', 'h', 'y', 'a', 'p', ' ', 'R', 'a', 'j', '!']

 
strs = (''.join(char))
print (strs)
# Out:
# Kashyap Raj!

# %%
strs =''
a = ['a','b','c','d','e'] 
for i in a:
    strs = strs + i
 
print(strs)
# Out:
# abcde
