# %%
Reverse Words in a Given String in Python
Description:
Given a string, reverse the words 

Boundaries:
1. Limits on the length, what if the string has just the one word?
2. 

ref: 
https://www.geeksforgeeks.org/reverse-words-given-string-python/
https://www.geeksforgeeks.org/reverse-words-in-a-given-string/

# %%
string = "reverse the sentence in python"
s = string.split()[::-1]
" ".join(s)
# Out:
# 'python in sentence the reverse'

# %%
string = "reverse the sentence in python"
lst = string.split()
revSentence = ""
for wrd in lst:
    revSentence = wrd + ' ' + revSentence

revSentence
# Out:
# 'python in sentence the reverse '

# %%
string = "reverse the words in a given sentence using python"
s = string.split()[::-1]
print (" ".join(s))
# Out:
# python using sentence given a in words the reverse

# %%
def revSentence(sentence):
    words = sentence.split()
    revSentence = " ".join(reversed(words))
    return revSentence

if __name__ == "__main__":
    input = "reverse the words in a given sentence using python"
    print (revSentence(input))
# Out:
# python using sentence given a in words the reverse

# %% [markdown]
# ### Reverse Words Using backward Iteration
#
# Find all the words in string with the help of re.findall() function.
# Iterate over the list in backward manner.
# Join the words in a string with the help of join() function.

# %%
# Function to reverse words of string
import re
def revSentence(sentence):
	# find all the words in sentence
	words = re.findall('\w+', sentence)
	# Backward iterate over list of words and join using space
	reverse_sentence = ' '.join(words[i] for i in range(len(words)-1, -1, -1))
	# finally return the joined string
	return reverse_sentence

if __name__ == "__main__":
    sentence = "Python is a Crazy Language"
    print (revSentence(sentence))
# Out:
# Language Crazy a is Python
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\usha_\AppData\Local\Temp\ipykernel_35588\1744705944.py:5: SyntaxWarning: invalid escape sequence '\w'
#   words = re.findall('\w+', sentence)

# %% [markdown]
# ### Reverse words using stack

# %%
string = "python is a crazy language"
stack = []
for word in string.split():
    stack.append(word)
revWords = []
while stack:
    revWords.append(stack.pop())
print ("Original Sentence:\n",string)
print (" ".join(revWords))
# Out:
# Original Sentence:
#  python is a crazy language
# language crazy a is python

# %% [markdown]
# ### Reverse Words Using split() python

# %%
def reverseWords(string):
    words = string.split()
    revString = ""
    for i in range(len(words)-1, -1, -1):
        revString += words[i] + ' '
    return revString.strip()

string = "python is a crazy language"
revWords = reverseWords(string)
print (revWords)
# Out:
# language crazy a is python

# %% [markdown]
# ### Reverse words in a string
#
# https://www.geeksforgeeks.org/reverse-words-in-a-given-string/

# %% [markdown]
# ### Using split, reverse and join

# %%
string = "Python is a crazy language"

# Python program to reverse words in a string

def reverse_words(str):
    
    # Split the input string by '.' while 
    # ignoring multiple consecutive dots
    words = [word for word in str.split('.') if word]
    
    # Reverse the words
    words.reverse()
    
    # Join the reversed words back into a string
    return '.'.join(words)


if __name__ == "__main__":
    str = "..geeks..for.geeks."
    print(reverse_words(str))
# Out:
# geeks.for.geeks

# %% [markdown]
# ### Using stack

# %%
# Python program to reverse words in a string

def reverse_words(str):
    stack = []
    word = ""
    # Iterate through the string
    for ch in str:
      
        # If not a dot, build the current word
        if ch != '.':
            word += ch
       
        # If we see a dot, push the word into the stack
        elif word:
            stack.append(word)
            word = ""

    # Last word remaining, push it to stack
    if word:
        stack.append(word)

    # Rebuild the string from the stack
    return ".".join(stack[::-1])

if __name__ == "__main__":
    str = "..geeks..for.geeks."
    print(reverse_words(str))
# Out:
# geeks.for.geeks

# %%
### Using Two Reverses

# %%
# Python program to reverse words in a string

def reverseWords(s):
  
    # reverse the whole string
    s = s[::-1]

    n = len(s)
    i = 0
    result = []

    l = 0
    while l < n:
        if s[l] != '.':
          
            # go to the beginning of the word
            if i != 0:
                result.append('.')
                i += 1

            # go to the end of the word
            r = l
            while r < n and s[r] != '.':
                result.append(s[r])
                i += 1
                r += 1

            # reverse the word
            result[i - (r - l):i] = reversed(result[i - (r - l):i])

            # move to the next word
            l = r
        l += 1

    return ''.join(result)


if __name__ == "__main__":
    s = "..geeks..for.geeks."
    print(reverseWords(s))
# Out:
# geeks.for.geeks
