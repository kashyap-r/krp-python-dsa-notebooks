# %% [markdown]
# In this puzzle you have given a string and you have to calculate average word length from a string
#
# Input:
# str = 'Hi I am Pawan. I am here only'
#
# output

# %%
str = 'Hi I am Pawan. I am here only'

words = str.split()

print (words)
# Out:
# ['Hi', 'I', 'am', 'Pawan.', 'I', 'am', 'here', 'only']
