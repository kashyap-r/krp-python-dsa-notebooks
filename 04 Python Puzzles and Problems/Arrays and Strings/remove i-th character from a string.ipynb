# %%
# Ways to remove ith character from a string

https://www.geeksforgeeks.org/python-string-replace/

# %%
#  Using replace()

s = 'Kashyap RajPurohit'
s = s.replace('P', 'p')
print (s)
# Out:
# Kashyap Rajpurohit

# %%
#  just replace first two occurances

s = 'Kashyap RajPurohita'
s = s.replace('a', 'A', 2)
print (s)
# Out:
# KAshyAp RajPurohita
