# %% [markdown]
# # find the number of times a character occurs in an array
# arr = 'kashyap'
#
#
# Intuition:
# 1. Identify the string
# 2. Then "identify" which character you want to "find" "/ search" for >
# 3. Then evolve the solution
# 4.

# %%
srchStr = 'kashyap rajpurohit'
srchChar = 'a'
count = 0 

for i in srchStr:
    if srchChar == i:
        count += 1

print (f"The character {srchChar} appears {count} times in the string!")
# Out:
# The character a appears 3 times in the string!

# %%
a = 'Philadelphia'
b = []
fn = 'i'
 
for i in range( 0 , len(a) ):
    if a[i] == fn:
        b.append(i)
# returns the postition of the character in the string 
print(b)
# Out:
# [2, 10]
