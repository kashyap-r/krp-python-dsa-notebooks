# %%
"""
Nth term of AP from first two terms

Arimatic Series: In an Arithmetic Series, the difference between all pair of consecutive terms is same

Given two intergers a1 and a2, the first and second terms of an arithmatic series respectively, the problem is to find the nth term of the series.

Questions and Considerations:
1. whether the numbers can be 0 or LT 0 or negative
2. Whether the numbers
3. Check input numbers must be first and second terms of an AP

Ex: a1 = 2, a2 = 3, n = 4
THe series is : 2, 3, 4, 5, 6, ...
4th term is 5

Input: a1 = 1, a2 = 3, n = 10

"""

# %%
# Method 1 -

def nthTermOfAP(a1, a2, a3):
    nthTerm = a1
