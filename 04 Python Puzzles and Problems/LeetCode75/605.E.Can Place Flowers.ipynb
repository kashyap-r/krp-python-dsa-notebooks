# %%
"""
605. Can Place Flowers
Easy

You have a long flowerbed in which some of the plots are planted, and some are not. However, flowers cannot be planted in adjacent plots.

Given an integer array flowerbed containing 0's and 1's, where 0 means empty and 1 means not empty, and an integer n, return true if n new flowers can be planted in the flowerbed without violating the no-adjacent-flowers rule and false otherwise.

Example 1:
Input: flowerbed = [1,0,0,0,1], n = 1
Output: true

Example 2:
Input: flowerbed = [1,0,0,0,1], n = 2
Output: false

Constraints:
1. Validate input for an integer (assume the array to be static - values pre-determined
2. any size constraints that needs to be taken care of w.r.t the array
"""

# %%
class Solution:
    def canPlaceFlowers(self, flowerbed: list[int], n: int) -> bool:
        right = flowerbed[len(flowerbed) - 1]
        length = len(flowerbed)

        for i in range(len(flowerbed)):
            right = flowerbed[length - i + 1] ||

            if flowerbed[i] == 0 and flowerbed[i-1] == 0 and flowerbed[length - i - 1] == 0:
                print (i, right)
                flowerbed[i] = 1
                n -= 1
        if n == 0:
            print (flowerbed)
            return True

        else:
            print (flowerbed)
            return False

sol = Solution()
flowerbed = [1,0,0,0,0,1]
n = 2
res = sol.canPlaceFlowers(flowerbed, n)
if res:
    print("yes")
else:
    print("no")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 24
#      22 flowerbed = [1,0,0,0,0,1]
#      23 n = 2
# ---> 24 res = sol.canPlaceFlowers(flowerbed, n)
#      25 if res:
#      26     print("yes")
#
# Cell In[31], line 7, in Solution.canPlaceFlowers(self, flowerbed, n)
#       4 length = len(flowerbed)
#       6 for i in range(len(flowerbed)):
# ----> 7     right = flowerbed[length - i + 1]
#       9     if flowerbed[i] == 0 and flowerbed[i-1] == 0 and flowerbed[length - i - 1] == 0:
#      10         print (i, right)
#
# IndexError: list index out of range

# %%
flowerbed = [1,0,0,0,0,1]

flowerbed = [1,2,3,4,5,6]
for i in range(len(flowerbed)):
    print (flowerbed[len(flowerbed)-i-1])


# right = flowerbed[len(flowerbed) - 1]
# print (right)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1

# %%
flowerbed = [1,0,0,0,0,1]
n = 1
targetslots = flowerbed.count(1) + n
emptyslots = flowerbed.count(0) - n

result = abs(targetslots - emptyslots)
# print (result)
print (True if result == 1 else False)
# Out:
# False
