# %%
"""
3. Longest Substring Without Repeating Characters
Medium
Topics
conpanies iconCompanies
Hint

Given a string s, find the length of the longest
without duplicate characters.

Hint: Generate all possible substrings & check for each substring if it's valid and keep updating maxLen accordingly.

Approach:
- The longest string should be
    * Substring
    * Without repeating characters

You just need to check that there are no repeated characters within a consecutive string of characters. To achieve this, you need to keep track of the characters currently forming the string. For this purpose, I considered three algorithms: one combining a sliding window and a set, and the second using a sliding window and a hash-based algorithm. The thrid is that the last position where each character was seen.

Approach:
You just need to check that there are no repeated characters within a consecutive string of characters. To achieve this, you need to keep track of the characters currently forming the string. For this purpose, I considered three algorithms:
- one combining a sliding window and a set, and
- the second using a sliding window and a hash-based algorithm.
- The third is that the last position where each character was seen.


"""

# %%
"""
Solution 1 - Sliding Window & Set

"""

# %%
s = "ashKash"

seen = []

for i in range(len(s)):
    if s[i] not in seen:
        seen.append(s[i])
