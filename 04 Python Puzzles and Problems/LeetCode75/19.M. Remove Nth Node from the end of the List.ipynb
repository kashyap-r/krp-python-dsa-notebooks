# %%
"""
Given the head of a linked list, remove the nth node from the end of the list and return its head.

Input: head = [1,2,3,4,5], n = 2
Output: [1,2,3,5]

"""

# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def removeNthFromEnd(self, head, n):
        pass

sol = Solution()
nodes = []
for i in range(1, 6):
    n = ListNode(i); nodes.append(n)

for i in nodes:
    print (i.val)

type (nodes)
# Out:
# 1
# 2
# 3
# 4
# 5
# list
