# %% [markdown]
# """
# Write a program for Armstrong NUmbers
# Problem: Determine whether a given number is Armstrong number or not
#
# A poitibe integer of n digits is called an armstrong number of order n if
#
# abcd = pow(a, n) + pow(b, n) + pow(c, n)+pow(d, n)
#
# Ex.
# Input n = 153
# Output = True
# To verify whether 153 = 1 * 1 * 1 + 5 * 5 * 5 + 3 * 3 * 3 = 153 = True
#
# Input: n = 9474
# Output = True
#
# """

# %%
# Approach 1: Naive Approach 
"""
1. find the length of the number 
2. Extract each digit and raise it by the power of length
3. Check if the sum of all values is equal to the number

"""

def checkArmstrong(num):
    return True

if __name__=="__main__":
    # Just accept input at command line
    # num = int(input())
    # print (f"datatype = {type(num)}, value={num}")
    num = 153
    print (f"The number {num} is Armstrong number" 
    if checkArmstrong(num) else f"The number {num} is not an Armstrong number")
# Out:
# The number 153 is Armstrong number
