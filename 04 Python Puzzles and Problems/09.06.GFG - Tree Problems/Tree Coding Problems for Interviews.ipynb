# %% [markdown]
# Refrences:
#
# 1. https://www.geeksforgeeks.org/dsa/binary-tree-data-structure/
#
# 2. https://www.geeksforgeeks.org/dsa/top-50-tree-coding-problems-for-interviews/
