# %%
n = 5 

f(n) = 1 + 2 + 3 + 4 + 5 
     = 15 

f(n) = (n(n+1))/2

# %%
n = 6 

sumn = (n * (n + 1))/2
int(sumn)
# Out:
# 21

# %%
# Sum of first n natural numbers 
def sumNatural(n):
    if n == 0 or n == 1:
        return n 
    else:        
        return n + sumNatural(n-1)

num = 5
result = sumNatural(num)
print (result)
# Out:
# 15
