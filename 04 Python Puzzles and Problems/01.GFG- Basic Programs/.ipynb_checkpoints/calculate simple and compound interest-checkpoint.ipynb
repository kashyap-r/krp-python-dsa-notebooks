# %% [markdown]
# Simple Interest formula:
#     Simple Interest = (P * T * R) / 100
#     Where P is the Principal amount
#     T is the time
#     R is the rate of interest
#
# Edge Case Scenarios:
# 1. Principal > 0
# 2. Interest >= 0
# 3. Time > 0
# 4. Are there any upper limits for any of these ?
# 5.

# %%
def simpleInterest(p, t, r):
    print (f"The principal amount is: {p}")
    print (f"The time period is: {t}")
    print (f"The rate of interest is: {r}")

    si = (p * t * r) / 100
    print (f"The Simple Interest is: {si}")
    return si

simpleInterest (100000, 6, 8)
# Out:
# The principal amount is: 100000
# The time period is: 6
# The rate of interest is: 8
# The Simple Interest is: 48000.0
# 48000.0

# %% [markdown]
# Time complexity: O(1)
# Auxiliary Space: O(1)

# %%
# Python3 program to find simple interest
#  principal amount, time and
# rate of interest taken from user.


def simple_interest(p,t,r):
    print('The principal is', p)
    print('The time period is', t)
    print('The rate of interest is',r)
    
    si = (p * t * r)/100
    
    print('The Simple Interest is', si)
    
    
# Driver code
P = int(input("Enter the principal amount :"))
T = int(input("Enter the time period :"))
R = int(input("Enter the rate of interest :"))
simple_interest(P,T,R)

# %% [markdown]
# ### Program to compute the compound Interest
#
# The formula to calculate compound interest annually is given by:
#
#     A = P(1 + R/100)^t
#
#     Compound Interest = A - P
#
#     Where,
#     A is the Amount
#     P is the Principal Amount
#     R is the rate of interest
#     T is the time period

# %%
def compoundInterest(principal, rate, time):
    Amount = principal * (pow((1 + rate / 100), time))
    CI = Amount - principal 
    return CI 

print (f"Compound Interest is : {compoundInterest(10000, 10.25, 5)}")
# Out:
# Compound Interest is : 6288.946267774416

# %% [markdown]
# Time Complexity: O(1) since no loop is used the algorithm takes up constant time to perform the operations
# Auxiliary Space: O(1) since no extra array is used so the space taken by the algorithm is constant.

# %%
# With user input 

# Python3 program to find compound
# interest for input taking from user.


def compound_interest(principal, rate, time):

	# Calculates compound interest
	Amount = principal * (pow((1 + rate / 100), time))
	CI = Amount - principal
	print("Compound interest is", CI)


# Driver Code
#Taking input from user.
principal = int(input("Enter the principal amount: "))
rate = float(input("Enter rate of interest: "))
time = int(input("Enter time in years: " ))
#Function Call
compound_interest(principal,rate,time)
# Out:
# Enter the principal amount:  100
# Enter rate of interest:  5.25
# Enter time in years:  4
# Compound interest is 22.71239094140624

# %%
# Compound INterest without using power function

def compoundInterest(principal, rate, time):
    Amount = principal * ((1 + rate / 100) ** time)
    CI = Amount - principal 
    return CI 

print (f"Compound Interest is : {compoundInterest(100, 5.25, 4)}")
# Out:
# Compound Interest is : 22.71239094140624

# %%
# Compounf interest using for loop 

def compoundInterset(principal, rate, time):
    Amount = principal 
    for i in range (time):
        Amount = Amount * (1 + rate/ 100)

    CI = Amount - principal
    return CI 

print (f"Compound Interest is: {compoundInterest(1200, 5.4, 2)}")
# Out:
# Compound Interest is: 133.0992000000001
