# %%
# using built-in 

a = 8
b = 0 
print (max(a, b))
# Out:
# 8

# %%
# Using conditional statements 

a = 5
b = 7
if a > b:
    print ("max = ", a)
else:
    print ("max = ", b)
# Out:
# max =  7

# %%
# Using ternary operator 

a = 9 
b = 8
res = a if a > b else b
print (res)
# Out:
# 9
