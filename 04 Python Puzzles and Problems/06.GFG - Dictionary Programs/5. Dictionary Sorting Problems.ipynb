# %% [markdown]
# 1️⃣ Sort dictionary by value DESC, break ties by key ASC
#
# 📌 Problem statement
#
# Given a dictionary of products and their sales count, sort it such that:
#     Higher sales come first
#     If two products have the same sales, sort alphabetically by product name
#
#
# Edge Cases:
# 1. What if any of the dictionaries product or sales is empty ?
# 2. What if sales count of one or more products is zero or -ve ?
# 3. Can the same product have two records with different counts, same counts ?
#     i.e. Data discrepancy... what is the action taken ?
# 4.

# %% [markdown]
# 2️⃣ Sort dictionary by length of key, then by value
# 📌 Problem statement
#
# Given a dictionary of usernames and scores:
#
#     Sort by length of username (shorter first)
#
#     If same length, sort by score descending

# %% [markdown]
# 3️⃣ Sort dictionary by computed metric (value / key length)
# 📌 Problem statement
#
#     You are given words and their frequency count.
#
#     Sort the dictionary by frequency per character, highest first.

# %% [markdown]
# 4️⃣ Sort dictionary of lists by aggregate value
# 📌 Problem statement
#
#     Given students and their marks in multiple subjects, sort students by average score, highest first.

# %% [markdown]
# 5️⃣ Sort dictionary by custom priority order + value
# 📌 Problem statement
#
# You are given task priorities:
#
#     Priority order: "HIGH" > "MEDIUM" > "LOW"
#
#     Within same priority, sort by task duration (ascending)
