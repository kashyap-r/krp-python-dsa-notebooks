# %%
## How to Reverse a String using Stack

Ref:
    https://www.geeksforgeeks.org/stack-set-3-reverse-string-using-stack/?ref=next_article

# %%
Given a string, reverse it using stack. 

Example:


Input: str = “GeeksQuiz”
Output: ziuQskeeG


Input: str = “abc”
Output: cba

# %%
class Stack:
    def __init__(self):
        self.s1 = []

    def push(self, value):
        self.s1.append(value)

    def size(self):
        return len(s1)
    
    def display(self):
        for item in self.s1:
            print(item, end=" ")

    def pop(self):
        if len(self.s1) == 0:
            return None 
        self.s1.pop()

    
        

stk = Stack()

stk.push('Kash Raj')
# stk.display()
# stk.pop()
stk.display()
# stk.display()
# Out:
# Kash Raj Kash Raj
