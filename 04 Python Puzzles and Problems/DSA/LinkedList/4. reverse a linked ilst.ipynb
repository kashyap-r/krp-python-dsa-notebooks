# %% [markdown]
# ### 1. Reversing a linked list - Using Iterative Method
#
# The idea is to reverse the links of all nodes using three pointers:
#
# prev: POinter to keep track of th previous node.
# curr: pointer to track the currrent node.
# next: pointer to ttrack the next node.
#
# #### O(n) Time and O(1) Space

# %% [markdown]
# Starting from the first node, initialize curr with the head of linked list and next with the next node of curr. Update the next pointer of curr with prev. Finally, move the three pointer by updating prev with curr and curr with next.
#
# Steps:
# 1. Initialize the three pointers
#        - **prev** as None / NULL
#        - curr as head
#        - next as None
#
# 2. Iterate through the linked list. In a loop do the following...
#     - Store the next node, next = curr->next
#     - prev = curr -> next

# %%
class Node:
    def __init__(self, value):
        self.value = value 
        self.next = None

    # Given the list, reverse the list and return the head of the list

# %% [markdown]
# ### Interchange fisrt and last elements of a linked list

# %% [markdown]
# ### INterchange any two elements of a linked list
