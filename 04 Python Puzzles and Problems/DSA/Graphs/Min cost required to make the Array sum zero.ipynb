# %% [markdown]
# Min cost required to make the Array sum zero consisting of 1 and -1
#
# https://www.geeksforgeeks.org/min-cost-required-to-make-the-array-sum-zero-consisting-of-1-and-1/?ref=next_article
