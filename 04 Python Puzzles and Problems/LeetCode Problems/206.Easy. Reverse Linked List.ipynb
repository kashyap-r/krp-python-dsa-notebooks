# %% [markdown]
# https://leetcode.com/problems/reverse-linked-list/description/
#
#
# https://www.geeksforgeeks.org/reverse-a-linked-list/
#
#
# 206. Reverse Linked List
#
# Given the head of a singly linked list, reverse the list, and return the reveresed list.

# %%
class Node:
    def __init__(self, val=0, next=None):
        self.val = val 
        self.next = next 

class Solution:

# %%
class Node:
    def __init__(self, value):
        self.val = value 
        self.next = None 

# 1- 2- 3 -4
def revListByIteration(head):
    prev = None
    curr = head 
    while curr is not None:
        nextNode = curr.next 
        curr.next = prev 
        prev = curr
        curr = nextNode
    return prev 

def printList(node):
     
    while node is not None:
        print (node.val, end=' -> ')
        node = node.next
    print('None')

def hasCycle(head):
    slowPtr = head 
    fastPtr = head 
    while slowPtr and fastPtr and fastPtr.next:
        slowPtr = slowPtr.next 
        fastPtr = fastPtr.next.next         
        if slowPtr == fastPtr:
            return True
    return False 

head = Node(1)
head.next = Node(2)
head.next.next = Node(3)
head.next.next.next = Node(4)
head.next.next.next.next = Node(5)
head.next.next.next.next.next = Node(6)
print("Given Linked List:")
printList(head)

# head.next.next.next.next = head

# head = revListByIteration(head)
# print("Reversed Linked List:", end="")
# printList(head)

if hasCycle(head):
    print ("List has Cycle")
else:
    print ("List does not have cycle")
# Out:
# Given Linked List:
# 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> None
# List does not have cycle

# %%
# Reverse a linked list using a stack 
class Node:
    def __init__(self, value):
        self.val = value 
        self.next = None 

def revListByStack(head):
    # create a stack 
    stack = []
    temp = head 
    # push all the nodes except the last node
    while temp.next is not None:
        stack.append(temp)
        temp = temp.next
    # make the last node as the haed of the linked list 
    head = temp 
    print("I'm here")
    while stack:
        # append the top value of stacj in list
        temp.next = stack.pop()
        temp = temp.next 
    temp.next = None
    return head

def printList(node):
    while node:
        print (node.val, end='->')
        node = node.next
    print ('None')

head = Node(1)
head.next = Node(2)
head.next.next = Node(3)
head.next.next.next = Node(4)
head.next.next.next.next = Node(5)

print("Given Linked List:", end="")
printList(head)
revList = revListByStack(head)
print("Reversed Linked List:", end="")
printList(revList)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None

    def insert_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        last_node = self.head
        while last_node.next:
            last_node = last_node.next
        last_node.next = new_node

    def reverse(self):
        prev = None
        current = self.head
        while current:
            next = current.next  # Store the next node
            current.next = prev  # Reverse the link
            prev = current       # Move prev to current
            current = next       # Move to the next node
        self.head = prev         # Update the head to the last node

    def print_list(self):
        current = self.head
        while current:
            print(current.data, end=' -> ')
            current = current.next
        print('None')

# Example Usage
sll = SinglyLinkedList()
sll.insert_at_end(1)
sll.insert_at_end(2)
sll.insert_at_end(3)

print("Original List:")
sll.print_list()  # Output: 1 -> 2 -> 3 -> None

sll.reverse()

print("Reversed List:")
sll.print_list()  # Output: 3 -> 2 -> 1 -> None
