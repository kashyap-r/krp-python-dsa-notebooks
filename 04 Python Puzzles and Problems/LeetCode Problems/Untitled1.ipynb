# %%
https://www.youtube.com/shorts/Oe27y2DqeJY

# %%
nums = [2, 2, 1]
s = list(set(nums))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 nums = [2, 2, 1]
#       2 s = list(set(nums))
# ----> 4 (nums - s)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'
