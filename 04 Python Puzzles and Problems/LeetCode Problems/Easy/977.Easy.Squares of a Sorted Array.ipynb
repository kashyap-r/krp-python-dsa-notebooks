# %% [markdown]
# 977. Squares of a Sorted Array
#
# Given an integer array nums sorted in non-decreasing order, return an array of the squares of each number sorted in non-decreasing order.
#
# Example 1:
#
# Input: nums = [-4,-1,0,3,10]
# Output: [0,1,9,16,100]
# Explanation: After squaring, the array becomes [16,1,0,9,100].
# After sorting, it becomes [0,1,9,16,100].
#
# Example 2:
#
# Input: nums = [-7,-3,2,3,11]
# Output: [4,9,9Follow up: Squaring each element and sorting the new array is very trivial, could you find an O(n) solution using a different approach?,49,121]

# %%
nums = [-4,-1,0,3,10]
sqrdarr = [0]*len(nums)

for i in range(len(nums)):
    sqrdarr[i] = pow(nums[i], 2)

print (sqrdarr)
# Compare different sorting techniques /.. w.r.t time complexity
# Out:
# [16, 1, 0, 9, 100]

# %%
nums = [-4,-1,0,3,10]
n = len(nums)
for i in range(n-1):
    for j in range(i+1, n):
        if nums[i] > nums[j]:
            nums[i], nums[j] = nums[j], nums[i]

print (nums)
# Out:
# [-4, -1, 0, 3, 10]

# %%
nums = [-4,-1,0,3,10]
n = len(nums)
for i in range(n-1):
    for j in range(i+1, n):
        if nums[i] > nums[j]:
            nums[i], nums[j] = nums[j], nums[i]

print (nums)
# Out:
# [-4, -1, 0, 3, 10]

# %%
# accepted 
class Solution:
    def sortedSquares(self, nums: List[int]) -> List[int]:
        nums = [x * x for x in nums]
        return sorted(nums)
