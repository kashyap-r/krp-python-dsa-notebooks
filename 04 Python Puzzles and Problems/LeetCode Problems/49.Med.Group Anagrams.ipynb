# %% [markdown]
# ### 49. Group Anagrams
#
# Ref:  https://leetcode.com/problems/group-anagrams/

# %% [markdown]
# Given an array of strings strs, group the
# anagram
# together. You can return the answer in any orde
#
# Example 1:
#
# Input: strs = ["eat","tea","tan","ate","nat","bat"]
#
# Output: [["bat"],["nat","tan"],["ate","eat","te
#
# Explanation:
#     *   There is no string in strs that can be rearranged to form "bat
#     *    The strings "nat" and "tan" are anagrams as they can be rearranged to form each oth
#     *     The strings "ate", "eat", and "tea" are anagrams as they can be rearranged to form each ot
# er.
# a"]]r.

# %%
from collections import defaultdict

def group_anagrams(strs):
    anagrams = defaultdict(list)
    for s in strs:
        # Sort the string and use it as a key
        sorted_str = ''.join(sorted(s))
        anagrams[sorted_str].append(s)
    
    return list(anagrams.values())

# Example usage:
strs = ["eat", "tea", "tan", "ate", "nat", "bat"]
result = group_anagrams(strs)
print(result)
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
anagrams = defaultdict(list)
for s in strs:
    sorted_str = ''.

# %%
"""The join() method takes an iterable (such as a list, tuple, set, or dictionary) 
and joins its elements into a single string using a specified delimiter."""

d = {'Geek': 1, 'for': 2, 'Geeks': 3}
e = {'a': 'apple', 'b': 'ball', 'c':'cat'}
# Separator "_" is used to join keys into a single string
res = '_'.join(d)
print(res)

print (e.keys())
print (e.values())
print ('-'.join(e))
print ('-'.join(e.values()))
print ('-'.join(e.keys()))
# Out:
# Geek_for_Geeks
# dict_keys(['a', 'b', 'c'])
# dict_values(['apple', 'ball', 'cat'])
# a-b-c
# apple-ball-cat
# a-b-c
