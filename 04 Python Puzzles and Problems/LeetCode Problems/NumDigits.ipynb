# %%
### Find the number of digits in a number

# %%
num = 1234
print (f"Number of digits in the number {num} = {len(str(num))}")
# Out:
# Number of digits in the number 1234 = 4

# %%
import math

number = 12345
number_of_digits = math.floor(math.log10(number)) + 1

print(number_of_digits)  # Outputs: 5
# Out:
# 5
