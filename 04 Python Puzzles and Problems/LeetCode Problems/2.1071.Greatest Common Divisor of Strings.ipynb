# %% [markdown]
# ### 1071. Greatest Common Divisor of Strings
#
# For two strings s and t, we say "t divides s" if and only if s = t + t + t + ... + t + t (i.e., t is concatenated with itself one or more times).
#
# Given two strings str1 and str2, return the largest string x such that x divides both str1 and str
#
# Example 1:
#
# Input: str1 = "ABCABC", str2 = "ABC"
# Output: "ABC"
#
# Example 2:
#
# Input: str1 = "ABABAB", str2 = "ABAB"
# Output: "AB"
#
# Example 3:
#
# Input: str1 = "LEET", str2 = "CODE
#
#
# Possible Solutions:
#
# #1.
# Use regular expressions to search the occurance of str2 in str1
#
# print the output
#
# #2.
# Manually search for the str2 in str1 usng in operator
#
#
# Questions:
#     1. Do we print the output at the first occurance ?
#     2. Or do we check multiple occurances ?
#     3. Do we need to count the number of occurances ?
#
# Answer:
#     The objective is to find the "Greatest Common Divisor of the String" which is a single value !!?
#
# "
# Output: ""
# 2.

# %%
str1 = "Google"
str2 = "goo"

if str2 in str1:
    print ("found!")

else:
    print ("str NOT found")
# Out:
# str NOT found
