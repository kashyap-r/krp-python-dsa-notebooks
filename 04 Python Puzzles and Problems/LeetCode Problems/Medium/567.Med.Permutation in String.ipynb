# %% [markdown]
# ### 567. Permutation in String
#
# Given two strings s1 and s2, return true if s2 contains a
# permutatio
# of s1, or false otherwise.
#
# In other words, return true if one of s1's permutations is the substring of
#
# Example 1:
#
# Input: s1 = "ab", s2 = "eidbaooo"
# Output: true
# Explanation: s2 contains one permutation of s1 ("ba").
#
# Example 2:
#
# Input: s1 = "ab", s2 = "eidboaoo"
# Output: false
#  s2.

# %% [markdown]
# Hints:
#
# 1. How will you check whether one string is a permutation of another string?
# 2. One way is to sort the string and then compare. But, Is there a better way?
# 3. If one string is a permutation of another string then they must have one common metric. What is that?
# 4. Both strings must have same character frequencies, if one is permutation of another. Which data structure should be used to store frequencies?
# 5. What about hash table? An array of size 26?
