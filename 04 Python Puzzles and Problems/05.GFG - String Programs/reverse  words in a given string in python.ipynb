# %% [markdown]
# https://www.geeksforgeeks.org/reverse-words-given-string-python/?ref=next_article

# %%
# Using Split and Join 

s = "Kash Raj"
rev = ' '.join(s.split()[::-1])
print (rev)
# Out:
# Raj Kash

# %%
s = 'kashyap raj purohit'

temp = s.split()
print (temp)
temp = temp[::-1] 
print (temp)
# Out:
# ['kashyap', 'raj', 'purohit']
# ['purohit', 'raj', 'kashyap']
