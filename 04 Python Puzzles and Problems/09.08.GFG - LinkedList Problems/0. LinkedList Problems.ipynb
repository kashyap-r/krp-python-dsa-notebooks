# %% [markdown]
# https://www.geeksforgeeks.org/dsa/linked-list-data-structure/
#
# Reverse a singly LInked List
# https://www.geeksforgeeks.org/dsa/reverse-a-linked-list/
#
# https://www.geeksforgeeks.org/dsa/modify-contents-linked-list/
