# %% [markdown]
# ### Problem: Given a binary array nums, return the maximum number of consecutive 1's in the array.
#
# Explanation: The first two digits or the last three digits are consecutive 1s. The maximum number of consecutive 1s is 3.
#
# Input: nums = [1,1,0,1,1,1]
# Output: 3
#
# Input: nums = [1,0,1,1,0,1]
# Output:
#
# Constraints:
# 1. Is there a minimum size for the array to be considered ?
# 2. Is there a minimum size for the array to be considered ?
#
#  2.

# %%
nu
