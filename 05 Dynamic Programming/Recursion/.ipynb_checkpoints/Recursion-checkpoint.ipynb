# %% [markdown]
# # Call Stack

# %% [markdown]
# 4! = 4 * 3 * 2 * 1
# 3! = 3 * 2 * 1
# 2! = 2 * 1
# 1! = 1

# %%
def factorial(n):
    if n == 1:
        return 1 
    return n * factorial(n-1)

print (factorial(4))
# Out:
# 24
