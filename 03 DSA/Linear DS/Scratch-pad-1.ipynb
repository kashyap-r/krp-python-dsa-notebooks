# %% [markdown]
# # Singly Linked List

# %%
class Node:
    def __init__(self, x):
         self.data = x 
         self.next = None 

class SinglyLinkedList:
    def __init__(self):
        self.head = None 

    def insertAtBegin(self, x):
        newNode = Node(x) 
        if not self.head:
            self.head = newNode
            return 
        newNode.next = self.head 
        self.head = newNode
        
     
    def insertAtPos(self, pos, x):
        if pos < 1:
            return self.head 
        
        if pos == 1:
            self.insertAtBegin(x)
        
        curr = self.head
        for i in range (1, pos - 1):
            if curr is None:
                return self.head 
            curr = curr.head 
        
        # if position is greater than number of nodes
        if curr is None:
            return self.head         
        newNode = Node(x)
        newNode.next = curr.next
        curr.next = newNode

    def insertAtPos2(self, pos, data):
        if pos == 0:
            self.insertAtBegin(data)
        
        curr = self.head
        count = 0 
        while curr is not None and count < pos - 1:
            curr = curr.next 
            count += 1 
        
        newNode = Node(data)
        newNode.next = curr.next 
        curr.next = newNode 

    # Insert at a position after a given val
    def insertAtPosVal(self, val):
        pass

    # length of the linke list 
    def length(self):
        count = 0 
        curr = self.head 
        while curr:
            count+=1 
            curr = curr.next 
        return count 

    def insertAtEnd(self, x):
        if not self.head:
            self.insertAtBegin(x)

        curr = self.head 
        while curr: 
            curr = curr.next 
        newNode = Node(x)
        curr.next = newNode
        return self.head 
        


    def deleteAtBegin(self, x):
        pass

    def deleteAtPos(self, x):
        pass 

    def deleteAtEnd(self, x):
        pass 

    
    # Traversing a Linked LIst - Recursive approach 
    def traverseListRec(self):
        pass 

    # Traversing a Linked List - Iterative approach 
    def traverseList(self):
        while self.head is not None:
            print (self.head.data, end=" ") 
            if self.head.next is not None:
                print (" -> ", end = "")
            self.head = self.head.next 
        print()
