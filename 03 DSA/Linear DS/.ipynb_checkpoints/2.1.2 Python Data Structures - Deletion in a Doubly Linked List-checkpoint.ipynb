# %% [markdown]
# ## Deleting a Node in a Doubly Linked List
#
# ![Deletion-at-the-Beginning-of-Doubly-Linked-List.webp](attachment:6220a1ca-dfa8-4bdd-9c08-074b2645df95.webp)
#
# 3-ways:
# 1. Deletion at the beginning of the Doubly Linked List
# 2. Deletion at the end f the Doubly Linked List
# 3. Deletion at a specific position of the doubly linked list
#
# ### 1. Deletion at the beginning of the Doubly Linked List
# Steps:
# 1. Check if the list is empty, there is nothing to delete, return
# 2. Store the head pointer in a 'temp' variable
# 3. Update the head of the linked list to the node next to the current head, head = head.next
# 4. if the head is not  n ull, update the previous pointer of the new head to NULL, head.prev = Null

# %%
class Node:
    def __init__(Self, value):
        self.value = value 
        self
