# %%
# Singly Linked LIst

class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class singlyLinkedList:
    def __init__(self):
        self.head = None

    def insertAtBeginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def insertAfterPos(self, pos, data):
        if pos < 1:
            return self.head

        if pos == 1:
            new_node = Node(data)
            new_node.next = self.head
            return new_node

        curr = self.head
        for i in range(1, pos -1):
            if curr is None:
                return self.head
            curr = curr.head

        if curr is None:
            return self.head
        new_node = Node(data)
        new_node.next = curr.next
        curr.next = new_node
        return self.head

    def insertAtEnd(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return

        curr = self.head
        while curr.next:
            curr = curr.next
        curr.next = new_node

    def deleteAtPos(self, pos):
        pass

    def deleteAtBeginning(self, data):
        if self.head is None:
            return "List Empty"

        curr = self.head
        self.head = curr.next
        return self.head

    def deleteAtEnd(self, data):
        curr = self.head
        while curr.next:
            curr = curr.next



    def printList(self):
        curr = self.head
        while curr:
            print(curr.data, end="-> ")
            curr = curr.next
        print ("None")

if __name__ == "__main__":

    sll = singlyLinkedList()
    sll.insertAtBeginning(11)
    sll.insertAtBeginning(12)
    sll.insertAtEnd(13)
    sll.insertAtBeginning(14)
    sll.insertAtEnd(15)
    sll.insertAtBeginning(16)
    sll.printList()
    sll.insertAfterPos(2, 222)
    sll.printList()
# Out:
# 16-> 14-> 12-> 11-> 13-> 15-> None
# 16-> 222-> 14-> 12-> 11-> 13-> 15-> None

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class singlyLinkedList:
    def __init__(self):
        self.head = None

    def insertAtBeginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        return new_node

    def printList(self):
        temp = self.head
        while temp:
            print(temp.data, end=" ")
            temp = temp.next

if __name__ == '__main__':
    sll = singlyLinkedList()
    sll.insertAtBeginning(1)
    sll.printList()
