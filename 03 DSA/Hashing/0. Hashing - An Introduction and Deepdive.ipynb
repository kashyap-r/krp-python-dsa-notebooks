# %% [markdown]
# Reference:
#
# 1. https://www.geeksforgeeks.org/dsa/introduction-to-hashing-2/
# 2. Chatgpt
# 3. Various
#
# ## 🔹 1. What is Hashing?
#
# Hashing is a process that transforms input data (keys) into a fixed-length string or integer, known as a hash value, using a mathematical formula called a hash function. This technique is widely used in data storage, retrieval, and security applications due to its efficiency and reliability.
#
# ![image.png](attachment:image.png)
#
#
# #### Key Components of Hashing
#
# **Input Data (Key):** The input can be any data type, such as text, numbers, or files. This key is processed by the hash function to generate a hash value.
#
# **Hash Function:** This is the core of hashing. It maps the input data to a fixed-length output. For example, the SHA-1 algorithm processes data in 512-bit chunks and generates a 160-bit **hash value**. The function ensures that even minor changes in input produce significantly different outputs.
#
# **Hash Value:** The output of the hash function is a unique, fixed-length representation of the input. It is used for quick data lookups, authentication, or integrity checks.
#
# **Hash Table:** A data structure that stores key-value pairs. The hash value determines the index where the data is stored, enabling fast retrieval.
#
# Hashing = mapping data -> fixed-size value (hash code) using a hashig function.
#
# Ex. hash('apple')
#
# #### How Hashing Works"
#
#     1. Data Processing: The input data is divided into fixed-size blocks (e.g., 512 bits for SHA-1). If the data is smaller than the block size, it is padded.
#
#     2. Hash Calculation: The hash function processes each block, combining the results iteratively to produce a final hash value.
#
#     3. Storage or Verification: The hash value can be stored in a hash table for quick lookups or used to verify data integrity by comparing hash values.
#
# For example, consider storing strings like "ab", "cd", and "efg" in a hash table of size 7. Using a simple hash function (sum of character values mod table size):
#
# "ab" → (1 + 2) mod 7 = 3
#
# "cd" → (3 + 4) mod 7 = 0
#
# "efg" → (5 + 6 + 7) mod 7 = 4
#
# These values determine the storage locations in the hash table.
#
# #### Collision Handling
#
# Collisions occur when two inputs produce the same hash value. Common resolution techniques include:
#
#     - Separate Chaining: Storing multiple items at the same index using a linked list.
#
#     - Open Addressing: Finding the next available slot using methods like linear or quadratic probing.
#
# Applications of Hashing
#
#     - Password Storage: Hashing secures passwords by storing their hash values instead of the actual passwords.
#
#     - Data Authentication: Ensures data integrity by comparing hash values.
#
#     - Hash Tables: Enables efficient data retrieval in databases and caches.
#
#     - Blockchain: Verifies transaction integrity by linking blocks with hash values.
#
#     - Error Detection: CRC32 hashes detect data corruption in files.
#
# Hashing is a cornerstone of modern computing, offering speed, security, and reliability in various applications.

# %% [markdown]
# ### Hash Table Data Structure
#
# #### Overview
#
#     - One of the widely used data strucutre after arrays
#     - Mainly supports search, insert and delete in O(1) time on average which is more efficient that other popular data structures like arrays, LinkedList and Self Balancing BST.
#     - We use hashign for dictionaries, frequency counting, maintaining data for quick access by key, etc
#     - Real world application include database indexing, cryotgraphy, cachesm symbol table, and dictionaries
#
# There are two forms of hash typically implemented in programming languages
#
#     - Hash Set: Collection of unique keys (implemented as set in python)
#
#     - Hash map: Collection of key values pairs with keys being unique (implemented as dictionary in python)
#
# **Situation where Hash is not used !**
#
#     - Need to maintain sorted data along with search, insert and delete. We use a self Balancing BST in these cases.
#
#     - When strings are keys and we need operations like prefix search along with search, insert and delete. We use Trie in these cases.
#
#     - When we need operations like floor and ceiling aliong with search, insert and/ or delete. We use self balancing BST in these cases.
#
# #### Components of Hashing
#
# ![image.png](attachment:image.png)
#
# There are majorly three components of hashing:
#
#     1.Key: A Key which is fed as in input into the hash function can be anything like a string or an integer. This key is processed by the hash function to generate a hash value.
#
#     2. Hash Function:  Receives the input key and returns the index of any element in an array called hash table. The index is known as the hash index. It maps the input data to a fixed-length output.
#
#     For example, the SHA-1 algorithm processes data in 512-bit chunks and generates a 160-bit **hash value**. The function ensures that even minor changes in input produce significantly different outputs.
#
#     3. Hash Table: Typically is an array of lists. It stores the hash values corresponding to the keys. It stores data in an associative manner in an array where each data balu has its own index.
#
# #### How does hashing work ?
#
#     Suppose we have set of strings {"ab", "cd", "efg"} and we would liek to store it in a table.
#
#     Step 1: We know that hash functions (some mathematical formula) are used to caluclate the hash value which acts as the index of the data structure where the value will be stored
#
#     Step 2: So, lets assign "a" = 1, "b" = 2, ..etc, value based on position to all alphabetical characters
#
#     Step 3: Therefore, the numerical value by summation of all characters of the string:
#         * "ab" = 1 + 2 = 3
#         * "cd" = 3 + 4 = 7
#         * "efg" = 5 + 6 + 7 = 18
#
#     Step 4: Now assume, we have a table of size 7 to store these strings. The hash funciton that is used here is the **sum of the characters in the key mod table size**.
#
#     We can compute the location of the string in the array by taking the **sum(string) mode 7**
#
#     Step 5: We will then store
#         - "ab" as 3 mod 7 = 3
#         - "cd" as 7 mod 7 = 0, and
#         - "efg" as 18 mod 7 = 4
#
#     Mapping Key with indices of the array
#
#     0       1       2       3       4       5       6
#     cd                      ab      efg
#
#     ![image-2.png](attachment:image-2.png)
#
#     The above technique enables us to calculate the location of a given string by using a simple hash function and rapidly find the value that is stored in that location. Therefore the idea of hashing seems like a great way to store (key, value) pairs of the data in a table.

# %% [markdown]
# ### Hash Functions and Types of Hash Functions
#
# A hash function creates a mapping from an input key to an index in a hash table.
#
# - **Phone Numbers as input keys:** Consider a hash table of size 100. A simple example hash function is to consider the last two digits of phone numbers so that we have valid hash table indexes as output. This is mainly taking remainder when input phone number is divided by 100. Please note that taking first two digits of a phone number would not be a good idea for a hash function as there would be many phone number having same first two digits.
#
# - **Lowercase English Strings as Keys:** Consider a hash table of size 100. A simple way to hash the strings would be add their codes (1 for a, 2 for b, ... 26 for z) and take remainder of the sum when divided by 100. This hash function may not be a good idea as strings "ad" and "bc" would have the same hash value. A better idea would be to do weighted sum of characters and then find remainder.
#
# #### Key properties of Hash Functions:
#
#     - Determinstic: A hash function must consistently produce the same output for the same input
#     - Fixed Output size: The output of a hash function should have a fixed size, regardless of the size f the input
#     - Efficiency: Should be able to process input quickly
#     - Uniformity: the has function should distribute the has values uniformly across the output space to avoid clustering
#     - Pre-image resistance: It should be computationally infeasible to reverse the hash funciton, i.e. to find the original output given a hash value
#     - Collision Resistance It should be difficult to find two different inputs that produce the same hash value
#     - Avalanche Effect: A small change in the input should produce a significantly different hash value
#
# Applications of Hash Functions
#     Hash Tables: The most common use of hash functions in DSA is in hash tables, which provide an efficient way to store and retrieve data.
#
#     Data Integrity: Hash functions are used to ensure the integrity of data by generating checksums.
#
#     Cryptography: In cryptographic applications, hash functions are used to create secure hash algorithms like SHA-256.
#
#     Data Structures: Hash functions are utilized in various data structures such as Bloom filters and hash sets.

# %% [markdown]
# ### Types of Hash Functions
# There are many hash functions that use numeric or alphanumeric keys. This article focuses on discussing different hash functions:
#
#     - **Division Method**:
#         * divide the key by a prime number and use the remainder as the hash value
#         h(k) = k mode m, where k is the key and m is a prime number (ex. hash table size)
#         Advantages
#             - Simple to implement
#             - works well when m is a prime number
#         Disadvantages:
#             - poor distribution isf m not chosen wisely
#
#     - **Multiplication Method**:
#         * Here a constant A (0 < A < 1 ) is used to multiply the key. The fractional part of the product is then multiplied by m to get the has h value
#
#         h(k) = [m(kAmod1)] where [] denotes the floor function
#
#         Advantages:
#             - Less sensitive to the value of m
#
#         Disadvantages:
#
#             - More complex than division method
#
#
#     - **Mid-Square Method**:
#         Here the key is squared and the middle digits of the result are taken as hash value.
#         Steps:
#             1. Square the key
#             2. Extract the middle digits of the squared value
#
#         Advantages:
#             - produces a good distribution of hash values
#
#         Disadvantages:
#             - may require additional computational effort
#
#     - **Folding Method**:
#         Here the key is divided into equal halves, sum the parts, and then take the module with respect to m
#         Steps:
#             1. Divide the key into parts
#             2. Sum the parts
#             3. take the modulo m of the sums
#
#         Advantages:
#             - Simple nd easy to implement
#
#         Disadvantages:
#             - depends on the choice of the partitioning scheme
#
#     - **Cryptographic Hash Functions**:
#         Cryptograohic hash function are designed to be secure and are used in cryptography.
#         Ex. MD5, SHA-1, SHA-256, etc
#         Characteristics:
#             - Pre-image resistance
#             - Second Pre-image resistance
#             - Collision resistance
#
#         Advantages:
#             - High security
#
#         Disadvantages:
#             - Computationally intensive
#
#     - **Universal Hashing**:
#         Uses a family of hash functions to minimize the chance of collision for any given set of inputs.
#
#         h(k)=((a⋅k+b)modp)modm
#
#         Where a and b are randomly chosen constants, p is a prime number greater than m, and k is the key.
#
#         Advantages:
#             - Reduces the probability of collisions
#
#         Disadvantages:
#             - Requires more computation and storage
#
#     - **Perfect Hashing**:
#         Perfect hashing aims to create a collision-free hash function for a static set of keys. It guarantees that no two keys will hash to the same value.
#
#         Types:
#
#             Minimal Perfect Hashing: Ensures that the range of the hash function is equal to the number of keys.
#
#             Non-minimal Perfect Hashing: The range may be larger than the number of keys.
#
#         Advantages:
#             - No Collisions
#
#         Disadvantages:
#             - Complex to construct

# %% [markdown]
# ### String hashing using Polynomial rolling hash function
#
# Given a string str of length n, your task is to find its hash value using polynomial rolling hash function.
#
# Note: If two strings are equal, their hash values should also be equal. But the inverse need not be true.
#
# Input: str = "polynomial"
# Output: 948934983
#
# The Polynomial Rolling Hash Function
#
# Polynomial rolling hash function is a hash function that uses only multiplications and additions. The following is the function:
# hash(s)  = s[0] + s[1]⋅p+s[2]⋅p2+⋯+s[n−1]×p^(n−1) mod m
# or simply,
# hash(s) = ∑ i=0 to n−1 . s[i]⋅p^i mod m
#
# ![image.png](attachment:image.png)
#
# Where
#     - The input to the function is a string s of length n
#
#     - p and m are some positive integers
#
#     - The choice of p and m affects the perfomance and the sceurity of the hash function
#
#     - If the string s consists of only lower-case letters, then p = 31 is a good choice.
#
#     - Competitive programmers perfer using a larger value for P. Examples include 29791, 11111, 111111
#
#     - m shall necessarily be alarge prime since the probability of two keys colliding (i.e. producing the same hash) is mnearmy (1/m). 10^9 + 7 and 10^9 + 9 are widely used value of m
#
#     - The output of the function is the hash value of the string s which ranges between 0 and (m-1)  inclusive
#
# Below is the implmementation of the polynoial rolling hash function
#
# Time Complexity: O(n)
# Auxiliary Space: O(1)

# %%
# Function to find hash of a string 
def findHash(str):
    n = len(str)

    # p is a prime number, m is a large prime number
    p = 31
    m = int(1e9 + 7)

    hashVal = 0 
    pPow = 1 # stores p^i 

    # Now, calculate the hashvalue 
    for i in range(n): 
        hashVal = (hashVal + (ord(str[i]) - ord('a') + 1 ) * pPow) % m         
        pPow = (pPow * p) % m
    return hashVal

s = 'furnace'
print (findHash(s))

# string = s = 'geeksforgeeks', hash value = 609871790

# countermand= 524764380 , furnace= 524764380
# Out:
# 524764380

# %% [markdown]
# #### Collisions in Polynomial Rolling Hash
#
# Note: The above function produces the same hash value for two different strings
#
#  countermand= 524764380 , furnace= 524764380
#
#  Also, the strings  "answers” and “stead” produce the same hash value for p = 37 and m = 10^9 + 9
#
# Since the output of the Hash function is an integer in the range [0, m), there are high chances for two strings producing the same hash value.
#
# We can note that the value of m affects the chances of collision. We have seen that the probability of collision is 1/m. We can increase the value of m to reduce the probability of collision. But that affects the speed of the algorithm. Larger the value of m slower the algorithm.
#
# #### Collision Resolution
#
# We can reduce the probability of collision by generating a pair of hashes for a given string. The first hash is generated using p = 31 and m = 10^9 + 7,
# while the second hash is generated using p = 37 and m = 10^9 + 9.
#
# Why will this work?..
# We are generating two hashes using two different modulo values, m1 and m2. The probability of a collision is now (1/m1) × (1/m2). Since both m1 and m2 are greater than 10^9, the probability that a collision occurs is now
# less than 10^−18 which is so much better than the original probability of collision, 10^−9
#
# Below is given the implementation:
#
#     Time Complexity: O(n)
#     Auxiliary Space: O(1)

# %%
def findHash1(s):
    n = len(s)

    # p is a prime number
    # m is a large prime number
    p = 31
    m = int(1e9 + 7)

    # to store hash value
    hashVal = 0

    # to store p^i
    pPow = 1

    # Calculating hash value
    for i in range(n):
        hashVal = (hashVal + (ord(s[i]) - ord('a') + 1) * pPow) % m
        pPow = (pPow * p) % m
    return hashVal

# Function to find hash of a string
def findHash2(s):
    n = len(s)

    # p is a prime number
    # m is a large prime number
    p = 37
    m = int(1e9 + 9)

    # to store hash value
    hashVal = 0

    # to store p^i
    pPow = 1

    # Calculating hash value
    for i in range(n):
        hashVal = (hashVal + (ord(s[i]) - ord('a') + 1) * pPow) % m
        pPow = (pPow * p) % m
    return hashVal

s = "geeksforgeeks"
print(findHash1(s), findHash2(s))
# Out:
# 609871790 642799661

# %% [markdown]
# For further research on the Polynomial rolling hash function, refer to tbe below link
#
# https://www.geeksforgeeks.org/dsa/string-hashing-using-polynomial-rolling-hash-function/

# %% [markdown]
# ### Collision Resolution Techniques
#
# In Hashing, hash functions were used to generate hash values. The hash value is used to create an index for the keys in the hash table. The hash function may return the same hash value for two or more keys.
#
# When two or more keys have the same hash value, a collision happens. To handle this collision, we use Collision Resolution Techniques.
#
# ![image.png](attachment:image.png)
#
# #### Collision Resolution Techniques
#
# There are mainly two methods to handle collision:
#
#     - Separate Chaining
#
#     - Open Addressing
#
# ![image-2.png](attachment:image-2.png)
#
# 1) Separate Chaining
#
# Note: Continue from this page..
#
# https://www.geeksforgeeks.org/dsa/collision-resolution-techniques/
