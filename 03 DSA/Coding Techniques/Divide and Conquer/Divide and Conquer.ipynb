# %% [markdown]
# ### Divide and Conquer Technique
#
# References
# 1. https://www.geeksforgeeks.org/divide-and-conquer/?ref=lbp
# 2. https://www.geeksforgeeks.org/introduction-to-divide-and-conquer-algorithm/
# 3. https://www.geeksforgeeks.org/dynamic-programming-vs-divide-and-conquer/?ref=next_article
# 4.

# %%
# multplication of two matrices 

matrix_a = [[1, 2, 3],[4, 5, 6],[7, 8, 9]]
matrix_b = [[1, 1, 1],[2, 2, 2],[3, 3, 3]]
