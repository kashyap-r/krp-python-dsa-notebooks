# %%
# !pip install jupyter_contrib_nbextensions
# !pip install jupyter_nbextensions_configurator
jupyter contrib nbextension install --user
jupyter nbextension enable execute_time/ExecuteTime
# Out:
# Collecting jupyter_contrib_nbextensions
#   Using cached jupyter_contrib_nbextensions-0.7.0.tar.gz (23.5 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: ipython_genutils in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Collecting jupyter_contrib_core>=0.3.3 (from jupyter_contrib_nbextensions)
#   Using cached jupyter_contrib_core-0.4.2.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: jupyter_core in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter_contrib_nbextensions) (5.7.2)
# Collecting jupyter_highlight_selected_word>=0.1.1 (from jupyter_contrib_nbextensions)
#   Using cached jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl.metadata (730 bytes)
# Collecting jupyter_nbextensions_configurator>=0.4.0 (from jupyter_contrib_nbextensions)
#   Using cached jupyter_nbextensions_configurator-0.6.4-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: nbconvert>=6.0 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter_contrib_nbextensions) (7.10.0)
# Requirement already satisfied: notebook>=6.0 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter_contrib_nbextensions) (7.0.8)
# Requirement already satisfied: tornado in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter_contrib_nbextensions) (6.4.1)
# Requirement already satisfied: traitlets>=4.1 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter_contrib_nbextensions) (5.14.3)
# Requirement already satisfied: lxml in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter_contrib_nbextensions) (5.2.1)
# Requirement already satisfied: setuptools in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (69.5.1)
# Requirement already satisfied: jupyter-server in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.14.1)
# Requirement already satisfied: pyyaml in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0.1)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda3_2024.06-1\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in d:\anaconda3_2024.06-1\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.1.0)
# Requirement already satisfied: defusedxml in d:\anaconda3_2024.06-1\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in d:\anaconda3_2024.06-1\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda3_2024.06-1\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in d:\anaconda3_2024.06-1\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\anaconda3_2024.06-1\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in d:\anaconda3_2024.06-1\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in d:\anaconda3_2024.06-1\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.9.2)
# Requirement already satisfied: packaging in d:\anaconda3_2024.06-1\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda3_2024.06-1\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in d:\anaconda3_2024.06-1\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.15.1)
# Requirement already satisfied: tinycss2 in d:\anaconda3_2024.06-1\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (3.10.0)
# Requirement already satisfied: pywin32>=300 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (305.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in d:\anaconda3_2024.06-1\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in d:\anaconda3_2024.06-1\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in d:\anaconda3_2024.06-1\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.2.3)
# Requirement already satisfied: six>=1.9.0 in d:\anaconda3_2024.06-1\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in d:\anaconda3_2024.06-1\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: anyio>=3.1.0 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (8.6.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: ipykernel in d:\anaconda3_2024.06-1\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.0)
# Requirement already satisfied: babel>=2.10 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (4.19.2)
# Requirement already satisfied: requests>=2.31 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.32.2)
# Requirement already satisfied: fastjsonschema in d:\anaconda3_2024.06-1\lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.16.2)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda3_2024.06-1\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.5)
# Requirement already satisfied: idna>=2.8 in d:\anaconda3_2024.06-1\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.7)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda3_2024.06-1\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda3_2024.06-1\lib\site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in d:\anaconda3_2024.06-1\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2024.1)
# Requirement already satisfied: attrs>=22.2.0 in d:\anaconda3_2024.06-1\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda3_2024.06-1\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda3_2024.06-1\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda3_2024.06-1\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.0.7)
# Requirement already satisfied: rfc3339-validator in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\anaconda3_2024.06-1\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3_2024.06-1\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3_2024.06-1\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3_2024.06-1\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2024.8.30)
# Requirement already satisfied: comm>=0.1.1 in d:\anaconda3_2024.06-1\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in d:\anaconda3_2024.06-1\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in d:\anaconda3_2024.06-1\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (8.25.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\anaconda3_2024.06-1\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: nest-asyncio in d:\anaconda3_2024.06-1\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.0)
# Requirement already satisfied: psutil in d:\anaconda3_2024.06-1\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (5.9.0)
# Requirement already satisfied: decorator in d:\anaconda3_2024.06-1\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda3_2024.06-1\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\anaconda3_2024.06-1\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.43)
# Requirement already satisfied: stack-data in d:\anaconda3_2024.06-1\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: colorama in d:\anaconda3_2024.06-1\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.4.6)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in d:\anaconda3_2024.06-1\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions)
#   Downloading webcolors-24.8.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in d:\anaconda3_2024.06-1\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: pycparser in d:\anaconda3_2024.06-1\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda3_2024.06-1\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in d:\anaconda3_2024.06-1\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: arrow>=0.15.0 in d:\anaconda3_2024.06-1\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.2.3)
# Requirement already satisfied: executing in d:\anaconda3_2024.06-1\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda3_2024.06-1\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.5)
# Requirement already satisfied: pure-eval in d:\anaconda3_2024.06-1\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Using cached jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# Using cached jupyter_nbextensions_configurator-0.6.4-py2.py3-none-any.whl (466 kB)
# Downloading webcolors-24.8.0-py3-none-any.whl (15 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: jupyter_contrib_nbextensions, jupyter_contrib_core
#   Building wheel for jupyter_contrib_nbextensions (setup.py): started
#   Building wheel for jupyter_contrib_nbextensions (setup.py): finished with status 'done'
#   Created wheel for jupyter_contrib_nbextensions: filename=jupyter_contrib_nbextensions-0.7.0-py2.py3-none-any.whl size=23428799 sha256=207c88683b58aa95e4b5d9969a5d3f67d3e05d35580137a31017df8537952607
#   Stored in directory: c:\users\usha_\appdata\local\pip\cache\wheels\4d\e4\20\dd16cdbbddcfe309a4559ea16adfa75fa5c554cfd076f9dae8
#   Building wheel for jupyter_contrib_core (setup.py): started
#   Building wheel for jupyter_contrib_core (setup.py): finished with status 'done'
#   Created wheel for jupyter_contrib_core: filename=jupyter_contrib_core-0.4.2-py2.py3-none-any.whl size=17492 sha256=9908cb878c69e2b88ae03efc4f7d7ccbe34e2d91df76e595d50e5a211741e244
#   Stored in directory: c:\users\usha_\appdata\local\pip\cache\wheels\32\f9\af\259a6f50f8b89d972aa81e31808a0af14e8bfc6867fb16ed07
# Successfully built jupyter_contrib_nbextensions jupyter_contrib_core
# Installing collected packages: jupyter_highlight_selected_word, webcolors, uri-template, fqdn, isoduration, jupyter_contrib_core, jupyter_nbextensions_configurator, jupyter_contrib_nbextensions
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 jupyter_contrib_core-0.4.2 jupyter_contrib_nbextensions-0.7.0 jupyter_highlight_selected_word-0.2.0 jupyter_nbextensions_configurator-0.6.4 uri-template-1.3.0 webcolors-24.8.0

# %%
# %%time 
sum = 0 
for i in range(1000000):
    sum += i*2

print (sum)
# Out:
# 999999000000
# CPU times: total: 62.5 ms
# Wall time: 137 ms

# %%
# %%timeit

sum = 0 
for i in range(1000000):
    sum += i*2

print (sum)
# Out:
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 999999000000
# 68.8 ms ± 2.15 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%time 

def fib(n):
    if n <= 1:
        return n 
    return fib(n-1) + fib(n-2)

fib(23)
# Out:
# CPU times: total: 0 ns
# Wall time: 7 ms
# 28657

# %%
# %timeit CODE_LINE

# %%
import time
start = time.time()
"the code you want to test stays here"
end = time.time()
print(end - start)
# Out:
# 0.0

# %%
# %%timeit 

SOME_CELL_CODE

# %%
pip install ipython-autotime

# %%
# %load_ext autotime

# %%
# %unload_ext autotime

# %%
def sum_of_lists(N):
    total = 0
    for i in range(5):
        L = [j ^ (j >> i) for j in range(N)]
        total += sum(L)
    return total

# %prun sum_of_lists(1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 8
#       5         total += sum(L)
#       6     return total
# ----> 8 get_ipython().run_line_magic('prun', 'sum_of_lists(1000)')
#
# File D:\anaconda3_2024.06-1\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File D:\anaconda3_2024.06-1\Lib\site-packages\IPython\core\magics\execution.py:313, in ExecutionMagics.prun(self, parameter_s, cell)
#     311     arg_str += '\n' + cell
#     312 arg_str = self.shell.transform_cell(arg_str)
# --> 313 return self._run_with_profiler(arg_str, opts, self.shell.user_ns)
#
# File D:\anaconda3_2024.06-1\Lib\site-packages\IPython\core\magics\execution.py:335, in ExecutionMagics._run_with_profiler(self, code, opts, namespace)
#     333 prof = profile.Profile()
#     334 try:
# --> 335     prof = prof.runctx(code, namespace, namespace)
#     336     sys_exit = ''
#     337 except SystemExit:
#
# File D:\anaconda3_2024.06-1\Lib\cProfile.py:102, in Profile.runctx(self, cmd, globals, locals)
#     100 self.enable()
#     101 try:
# --> 102     exec(cmd, globals, locals)
#     103 finally:
#     104     self.disable()
#
# File <string>:1
#
# Cell In[27], line 5, in sum_of_lists(N)
#       3 for i in range(5):
#       4     L = [j ^ (j >> i) for j in range(N)]
# ----> 5     total += sum(L)
#       6 return total
#
# TypeError: 'int' object is not callable
