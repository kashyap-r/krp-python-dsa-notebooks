# %% [markdown]
# ###
# Coding Exercises
#
#     Leetcode - Easy -   3
#     Leetcode - Medium - 2
#     Leetcode - Hard -   1
#
#     Math Puzzles
#
#     String Problems
#
# Python
#
#     Python
#
# DSA Revision
#
#     Data Structures & Operations
#         - Stack
#         - Queue
#             * Circular Queue
#
#         - Linked List
#             - Singly Linked List
#             - Doubly Linked List
#         - Graphs
#         - Trees
#             - Binary Tree
#             - Binary Search Tree
#         - Heap
#
#     Sorting
#         - Selection Sort
#         - Bubble Sort
#         - Merge Sort
#         - Quick Sort
#         - Insertion Sort
#     Searching
#         - Sequential Search
#         - Binary Search
#         - BFS
#         - DFS
#         - Search Trees
#             * Height Balanced Trees
#             * Weight Balanced Trees
#             * Trie
#         - Hash-Table Methods
#             * Hashing Functions
#
# Other Algorithms (https://cp-algorithms.com/)
#     - Manhattan Distance
#     - Euclidean Distance -
#     - Knapsack Problem
#     - Hungarian Algorithm
#     - Tortoise and Hare Algorithm
#     - Finding faces of a planar graph
#     - BIT Manipulation
#     - Binary Search
#     - MEX ( Minimum Excluded element in an array)
#     - Factoring Exponentiation
#     - Knuth's Optimization
#     - Continued Fractions
#
# System Design Case Study (atleast 5 of them)
#
#
# ML Design
#     - Feature Selection
#
#
#
# Tech Leadership
#
#     - Conflicts
#         - TEM model post process scores migration
#
#     - Challenges
#         - WI Legacy model deployment
#
#     - Failures
#         - Features Validation during migration
#
#     - Successes
#         - CWE Migration
#         - Model Rebuild
#         -
