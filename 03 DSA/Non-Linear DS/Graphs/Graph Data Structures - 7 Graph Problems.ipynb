# %% [markdown]
# Problems in Graph
#
# 1. Number of Islands
#    https://www.geeksforgeeks.org/find-the-number-of-islands-using-dfs/?ref=lbp
# 2. Minimum steps to reach a destination
#    https://www.geeksforgeeks.org/minimum-steps-to-reach-a-destination/?ref=lbp
# 3. Longest path between any pair of vertices
#    https://www.geeksforgeeks.org/longest-path-between-any-pair-of-vertices/?ref=lbp
# 4. NUmber of Groups formed in a graph of friends
#    https://www.geeksforgeeks.org/number-groups-formed-graph-friends/?ref=lbp
# 5. Minimum number of swaps required to sort an array
#    https://www.geeksforgeeks.org/minimum-number-swaps-required-sort-array/?ref=lbp
# 6. Detect Cycle in an undirected graph
#    https://www.geeksforgeeks.org/detect-cycle-undirected-graph/?ref=lbp
# 7. Find if there is a path between two vertices in a directed graph
#    https://www.geeksforgeeks.org/find-if-there-is-a-path-between-two-vertices-in-a-given-graph/?ref=lbp
# 8. Minimum steps to reach target by a Knight
#    https://www.geeksforgeeks.org/minimum-steps-reach-target-knight/?ref=lbp
# 9. Word Search in a 2D grid of charaters
#    https://www.geeksforgeeks.org/search-a-word-in-a-2d-grid-of-characters/?ref=lbp
# 10. Print all paths from a given source to a destination
#     https://www.geeksforgeeks.org/find-paths-given-source-destination/?ref=lbp
# 11. Hard: Water connection problem
#     https://www.geeksforgeeks.org/water-connection-problem/?ref=lbp
# 12. Hard: Print all paths from a given source to destination
#     https://www.geeksforgeeks.org/find-paths-given-source-destination/?ref=lbp
