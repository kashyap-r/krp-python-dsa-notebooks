# %% [markdown]
# ### Find the word from a given sentence having given word as prefix
#
# https://www.geeksforgeeks.org/find-the-word-from-a-given-sentence-having-given-word-as-prefix/?ref=next_article

# %% [markdown]
# Problem Statement:
#     Given a string S representing a sentence and another string word, the task is to find the word from S which has the string word as a prefix. If no such word is present in the string, print -1
#
# Examples:
# Input: S = “Welcome to Geeksforgeeks”, word=”Gee”
# Output: Geeksforgeeks
# Explanation:
# The word “Geeksforgeeks” in the sentence has the prefix “Ge
#
# Input: s=”Competitive Programming”, word=”kdflk”
# Output: -1
# Explanation:
# No word in the string has “kdflk” as its prefi
# Constraints:
# 1. word < sentence
# 2. can sentence be one word ? word be one word
# 3. how about multiple spaces, special characters
# 4. does case matter ?
#
# Analysis
# 1. The "word" has to be a prefix for any word in the sentence !!.
#
# e”.

# %%
sentence = "My name is Kashyap"
word = 'Kash'
word in sentence
# Out:
# True

# %% [markdown]
# Approach:
# 1. convert the sentence into a list
# 2. check whether each item of the list has the 'word" in it ?
# 3. ensure that the "word" is actually a prefixx to any of the entities of the list

# %%
str = 'Kash'
word = 'Kashyap'

word[:len(str)]
# Out:
# 'Kash'
