# %% [markdown]
# Reference:
# https://www.geeksforgeeks.org/reverse-the-sentence-using-stack/?ref=next_article

# %% [markdown]
# ### Reverse the Words of a String using Stack
#
# Problem Statement:
# Given string str consisting of multiple words, the task is to reverse the entire string word by word.
#
# Example:
# Input: str = “I Love To Code”
# Output: Code To Love I
#
# Input: str = “data structures and algorithms”
# Output: algorithms and structures data
#
# Constraints:
# 1. What if the input string is just one word
# 2. input string is empty, has multiple spaces
# 3. does case matter
# 4. what if the string has identical words

# %% [markdown]
# Approach:
# 1. Create an empty stack
# 2. traverse the entire string, while traversing add the characters of the string inot a temporary variable until you get space and push that temporary variable into a stack
# 3. repeat the above step until the end off the string
# 4. pop the words from the stack until the stack is not empty which will be in reverse order

# %%
def reverse(str):
    # create an empty stack 
    stk = []
    # create an empty temp string 
    temp = ''
    # traverse through the input string
    for i in range(len(stk)):
        if str[i] == ' ':
            # push temp variable into stack 
            stk.append(temp)
            # reassign temp variable as ""
            temp = ""
        else:
            temp = temp + str[i]

    stk.append(temp)
    while len(stk) != 0:
        temp = stk[len(stk)-1]
        print (temp, end=" ")

    print()

s = "DataStructures and Algorigthms"
reverse(s)

# %%
# Python3 implementation of 
# the above approach

# function to reverse the 
# words of the given string 
# without using strtok(). 
def reverse(s):

    # create an empty string 
    # stack
    stc = []
    
    # create an empty temporary
    # string
    temp = ""
    
    # traversing the entire string
    for i in range(len(s)):
    
    	if s[i] == ' ':
    	
        	# push the temporary variable 
        	# into the stack
        	stc.append(temp)
    	
        	# assigning temporary variable
        	# as empty
        	temp = ""		 
    
    	else:
        	temp = temp + s[i]
    
    # for the last word of the string
    stc.append(temp)
    
    while len(stc) != 0:
    
    	# Get the words in reverse order 
    	temp = stc[len(stc) - 1]
    	print(temp, end = " ")
    	stc.pop()
    
    print()

# Driver code
s = "I Love To Code"
reverse(s)
# Out:
# Code To Love I
