# %% [markdown]
# ### Find the level of a given node in an undirected graph
#
# Given an undirected graph with V vertices and E edges and a node X, the task is to find the level of node X in the undirected graph.
# If X does not exist in the graph then return -1
#
# Note: Traverse the graph starting from vertex 0.
#
# Examples:
#
#
#
#
# Constraints:
# - The starting point of the traversal must be given
#
# Edge-case Scenarios:
# - Whether the graph is connected? If not, we need to recursively traverse all the vertices.
# -
