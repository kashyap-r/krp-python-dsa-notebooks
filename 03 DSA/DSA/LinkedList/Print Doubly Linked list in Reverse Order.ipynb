# %% [markdown]
# ### Print Doubly Linked list in Reverse Order
#
# https://www.geeksforgeeks.org/print-doubly-linked-list-in-reverse-order/?ref=ml_lbp

# %% [markdown]
# Problem Statement:
#     Given a doubly-linked list of positive integers. The task is to print the given doubly linkked list data in reverse order.
#
# Examples:
#
# Input: List = 1 <=> 2 <=>  3 <=>  4 <=>  5
# Output: 5  4  3  2  1
#
# Input: 10 <=> 20 <=> 30 <=> 40
# Output: 40  30  20  10

# %% [markdown]
# Approach:
#
# - Take a pointer to the head of the doubly linked list
# - Now, start traversing through the linked list till the end
# - After reaching the last node, start traversing in backward direction and simultaneously print the node->data

# %%
class Node: 
    def __init__(seelf, data=0):
        self.data = 0 
        self.next = 0 
        self.prev = 0 

class DLL():
    def __init__(self):
        self.head = node() 

    def create(self, data):
        if self.head.data is 0:
            
            self.head.data = data 
            self.head.next = 0 
            self.head.prev = 0 
            
        elif self.head.next  is 0:
