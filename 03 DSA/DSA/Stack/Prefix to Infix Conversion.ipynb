# %% [markdown]
# ### Prefix to Infix Conversion
#
# Ref: https://www.geeksforgeeks.org/prefix-infix-conversion/?ref=next_article
#
# Infix : An expression is called the Infix expression if the operator appears in between the operands in the expression. Simply of the form (operand1 operator operand2).
# Example : (A+B) * (C-D)
#
# Prefix : An expression is called the prefix expression if the operator appears in the expression before the operands. Simply of the form (operator operand1 operand2).
# Example : *+AB-CD (Infix : (A+B) * (C-D) )
#
# Given a Prefix expression, convert it into a Infix expression.
# Computers usually does the computation in either prefix or postfix (usually postfix). But for humans, its easier to understand an Infix expression rather than a prefix. Hence conversion is need for human underst
#
# Examples:
# Input :  Prefix :  *+AB-CD
# Output : Infix : ((A+B)*(C-D))
#
# Input :  Prefix :  *-A/BC-/AKL
# Output : Infix : ((A-(B/C))*((A/K)
#
# ![image.png](attachment:8e852e0d-48f4-410b-8651-23e35726444d.png)-L))anding.

# %% [markdown]
# ### Algorithm for Prefix to Infix:
#     *
# Read the Prefix expression in reverse order (from right to lef
#     * )
# If the symbol is an operand, then push it onto the St
#     * ck
# If the symbol is an operator, then pop two operands from the St
#         ck
# Create a string by concatenating the two operands and the operator between th        em.
# string = (operand1 + operator + opera        nd2)
# And push the resultant string back t
#     *  Stack
# Repeat the above steps until the end of Prefix exp
#     * ession.
# At the end stack will have only 1 string i.e resulta
#     nt string

# %%
def isOperator(c):
    if c == "*" or c == "+" or c == "-" or c == "/" or c == "^" or c == "(" or c == ")":
        return True 
    else:
        return False

def prefixToInfix(prefix):
    stack = []

    i = len(prefix) - 1 
    while i >= 0:        
        if not isOperator(prefix[i]):            
            # symbol is operand 
            stack.append(prefix[i])
            i -= 1 
        else:
            # symbol is operator 
            str = "(" + stack.pop() + prefix[i] + stack.pop() + ")"
            stack.append(str)
            i -= 1
    return stack.pop()
            
    


if __name__ == "__main__":
    str = "*-A/BC-/AKL"
    print (prefixToInfix(str))
# Out:
# ((A-(B/C))*((A/K)-L))
