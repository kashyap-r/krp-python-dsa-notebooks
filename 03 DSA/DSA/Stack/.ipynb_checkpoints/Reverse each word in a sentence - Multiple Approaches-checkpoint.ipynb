# %%
Ref 

https://www.geeksforgeeks.org/python-reverse-word-sentence/

# %% [markdown]
# Given a long sentence, reverse each word of the sentence individually in the sentence itself. Examples:
#
# Input : Geeks For Geeks is good to learn
# Output : skeeG roF skeeG si doog ot nrael
#
# Input : Split Reverse Join
# Output : tilpS esreveR nioJ

# %% [markdown]
# Approach:
#
# 1. split the sentence into a list of words
# 2. reverse each word of the string in the list individually
# 3. join the words in the list to form back the sentence
#
# Functions:
# split()
# loops
# join()

# %%
# Approach #1 - Own logic 

class Solution:
    def reverseWordsinaSentence(self, sentence):
        wordList = sentence.split()
        revWordList = [word[::-1] for word in wordList]
        revSentence = " ".join(revWordList)
        return revSentence

    # This does NOT give the correct output 
    # This also is not called !!! Why ??
    def reverseWordsInPlace(self, sentence):
        revSentence = ""
        print (1)
        wordList = sentence.split()
        for word in wordList:
            revSentence += word[::-1]
        return ' '.join(revSentence)

    # In Python, when you define a function with the same name multiple times, 
    # the last definition overwrites the previous ones.
    # Hence the above function definition is unused or NOT called !!

    def reverseWordsInPlace(self, sentence):
        revSentence = []
        print (2)
        wordList = sentence.split()
        for word in wordList:
            revSentence.append(word[::-1])
        return ' '.join(revSentence)

Soln = Solution()
sentence = "My Name is Raj"

print ("Given Sentence:",sentence)
print (Soln.reverseWordsinaSentence(sentence))
print (Soln.reverseWordsInPlace(sentence))
# Out:
# Given Sentence: My Name is Raj
# yM emaN si jaR
# 2
# yM emaN si jaR

# %%
# Approach #2 
# Python code to Reverse each word
# of a Sentence individually

# Function to Reverse words
def reverseWordSentence(Sentence):

	# Splitting the Sentence into list of words.
	words = Sentence.split(" ")
	
	# Reversing each word and creating
	# a new list of words
	# List Comprehension Technique
	newWords = [word[::-1] for word in words]
	
	# Joining the new list of words
	# to for a new Sentence
	newSentence = " ".join(newWords)

	return newSentence

# Driver's Code 
Sentence = "GeeksforGeeks is good to learn"
# Calling the reverseWordSentence 
# Function to get the newSentence
print(reverseWordSentence(Sentence))
# Out:
# skeeGrofskeeG si doog ot nrael

# %%
# Approach #3

# Python code to Reverse each word
# of a Sentence individually

# Function to Reverse words
def reverseWordSentence(Sentence):

	# All in One line
	return ' '.join(word[::-1] for word in Sentence.split(" "))

# Driver's Code 
Sentence = "GeeksforGeeks is good to learn"
print(reverseWordSentence(Sentence))
# Out:
# skeeGrofskeeG si doog ot nrael

# %%
# Python code to Reverse each word
# of a Sentence individually
import re
# Function to Reverse words
def reverseWordSentence(Sentence):

	# substituting reverse word in place of word in sentence
	newSentence = re.sub('(\w+)', lambda x : x.group()[::-1], Sentence)

	return newSentence

# Driver's Code
Sentence = "GeeksforGeeks is good to learn"
# Calling the reverseWordSentence
# Function to get the newSentence
print(reverseWordSentence(Sentence))
# Out:
# skeeGrofskeeG si doog ot nrael
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\usha_\AppData\Local\Temp\ipykernel_34904\3500905501.py:8: SyntaxWarning: invalid escape sequence '\w'
#   newSentence = re.sub('(\w+)', lambda x : x.group()[::-1], Sentence)

# %% [markdown]
# # Approach 4
#
# Approach#4: Using map
# We can split the sentence into individual words using the split() method, and then use the map() function to apply the [::-1] slice operator to each word.
#
# Algorithm
# 1. Start by defining the function “reverse_words” that takes a single parameter “sentence”.
# 2. Split the “sentence” into individual words using the split function and store them in the variable “words”.
# 3. Define a lambda function that takes a string and returns its reverse. In this case, the lambda function is defined as “lambda x: x[::-1]”.
# 4. Apply the lambda function to each element in “words” using the map function and store the result in the variable “reversed_words”.
# 5. Join the elements in “reversed_words” into a single string with a space separating each element using the join function.
# 6. Return the resulting string

# %%
def reverse_words(sentence):
	words = sentence.split()
	reversed_words = list(map(lambda x: x[::-1], words))
	return ' '.join(reversed_words)
sentence = "GeeksforGeeks is good to learn"
print(reverse_words(sentence))
# Out:
# skeeGrofskeeG si doog ot nrael

# %%
sentence = "My Name is /* Kashyap"

words = sentence.split()
print (words )
revWord = []
for word in words:    
    revWord.append(word[::-1])

" ".join(revWord)
# -- Missed the spaces
# Out:
# ['My', 'Name', 'is', '/*', 'Kashyap']
# 'yM emaN si */ payhsaK'

# %%
class Stack:
    def __init__(self):

# %%
sentence = "My Name is Kashyap"

wordList = sentence.split()

for word in wordList:
    print (word)
    
for word in sentence:
    print (word)



for word in sentence:
    if word == " ":
        print ('Yay')
    else:
        print (word)
# Out:
# My
# Name
# is
# Kashyap
# M
# y
#
# N
# a
# m
# e
#
# i
# s
#
# K
# a
# s
# h
# y
# a
# p
# M
# y
# Yay
# N
# a
# m
# e
# Yay
# i
# s
# Yay
# K
# a
# s
# h
# y
# a
# p

# %%
sentence = "My Name is /* Kashyap"

words = sentence.split()
print (words )
revWord = []
for word in words:
    print (f"word={word}")
    for chr in range(len(word)):
        print (f"{chr}", end=" ")
    

# "".join(revWord)

# -- Missed the spaces
