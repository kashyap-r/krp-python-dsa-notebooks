# %%
"""
Task: Find the length of the string

Methods
1. use the built-in function len()
2.
"""

# %%
str1 = 'KAshyap'
print(len(str1))

count = 0

for ch in str1:
    count += 1
print (count)

print(str1.count("")-1)
# using enumerate function

cnt = 0
for i, a in enumerate (str1):
    cnt += 1

print (cnt)
# Out:
# 7
# 7
# 7
# 7
