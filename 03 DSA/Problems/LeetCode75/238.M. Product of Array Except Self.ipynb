# %%
"""
238. Product of Array Except Self

Given an integer array nums, return an array answer such that answer[i] is equal to the product of all the elements of nums except nums[i].

The product of any prefix or suffix of nums is guaranteed to fit in a 32-bit integer.

You must write an algorithm that runs in O(n) time and without using the division operation.

Example 1:

Input: nums = [1,2,3,4]
Output: [24,12,8,6]

Example 2:

Input: nums = [-1,1,0,-3,3]
Output: [0,0,9,0,0]

Follow up: Can you solve the problem in O(1) extra space complexity? (The output array does not count as extra space for space complexity analysis.)

"""

# %%
from math import prod
class Solution:
    def productExceptSelf(self, nums):
        prodarr = prod(nums)
        for i in range(len(nums)):
            nums[i] = int(prodarr / nums[i])
        return nums

sol = Solution()
print(sol.productExceptSelf(nums=[1,2,3,4]))
# Out:
# [24, 12, 8, 6]

# %%
# Out:
# 0

# %%
class Solution:
    def productExceptSelf(self, nums: list[int]) -> list[int]:
        n = len(nums)
        prod = [1]*n
        loopCnt = 0
        for k in range(n):
            for i in range(k+1, n):
                if i != k:
                    prod[k] *= nums[i]
        return prod

sol = Solution()
print(sol.productExceptSelf(nums=[1,2,3,4]))
# Out:
# [24, 12, 4, 1]

# %%
"""
This is a classic example of prefix sum problem

1D Prefix Sum (exclusive style: length n+1



"""

# %%
def prefix_sums(a):
    ps = [0]
    for x in a:
        ps.append(ps[-1] + x)
        return ps

def rangesum(ps, l, r):
    return ps[r+1] - ps[l]

a = [3, 1, 4, 2, 5]
ps = prefix_sums(a)
print (ps)

print (rangesum(ps, 1, 3))
# Out:
# [0, 3]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 14
#      11 ps = prefix_sums(a)
#      12 print (ps)
# ---> 14 print (rangesum(ps, 1, 3))
#
# Cell In[1], line 8, in rangesum(ps, l, r)
#       7 def rangesum(ps, l, r):
# ----> 8     return ps[r+1] - ps[l]
#
# IndexError: list index out of range
