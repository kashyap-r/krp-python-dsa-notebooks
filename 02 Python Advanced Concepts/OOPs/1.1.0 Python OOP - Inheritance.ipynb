# %% [markdown]
# ### Python Inheritance
#
# Ref:
# https://www.geeksforgeeks.org/inheritance-in-python/
#
# - Inheritance is the capability of one class to derive or inherit the properties from another class
# - The class that derives properties is called the derived class or child class
# - The class from from which the properties are being derived is called the base class or parent class
#
# Benefits
# - represents real-world relationships
# - provides reusability of a code
# - inheritance is transitive in nature i.e. if class B inherits from another class A, then all the subclasses of B would automatically inherit from class A
#
# Types of Inheritance
#
# * Single Inhertance: Single-level inheritance enables a derived class to inherit characteristics from a single-parent class.
# * Multilevel Inheritance: Enables a derived class to inherit properties from an immediate parent class which in turn inherits properties from its parent class.
# * Hierarchical Inheritance: enables more than one derived class to inherit properties from a parent class
# * Multiple Ineritance: enables one derived class to inherit properties from more than one base-class
#
# Syntax:
# Class BaseClass:
#     {Body}
# Class DerivedClass(BaseClass):
#     {Body}

# %%
# parent class 
class Person(object):
    
    # constructor 
    def __init__(self, name, idnum):
        self.name = name 
        self.idnum = idnum 

    def display(self):
        print (self.name)
        print (self.idnum)

    def details(self):
        print ("My name is {}".format(self.name))
        print ("My id is is {}".format(self.idnum))

class Employee(Person):
    def __init__(self, name, idnum, salary, designation):
        self.salary = salary 
        self.designation = designation

        # invoking the __init__ (constructr) of the Person (parent) class
        Person.__init__(self, name, idnum)

    def details(self):
        print("My name is {}".format(self.name))
        print("IdNumber: {}".format(self.idnum))
        print("Post: {}".format(self.designation))


a =  Employee('Kashyap', 'a658764', 200000, "Pro")
a.display()
a.details()
# Out:
# Kashyap
# a658764
# My name is Kashyap
# IdNumber: a658764
# Post: Pro
