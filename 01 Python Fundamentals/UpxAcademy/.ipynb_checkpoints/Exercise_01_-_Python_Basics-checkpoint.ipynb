# %% [markdown]
# # UpX Academy - Python Basics 01
# ## Exercise 01
#
# #### Variables
#
# ###### Hello World - variable
#
#     Store your own version of the message "Hello World" in a variable, and print it.
#
# ###### One Variable, Two Messages:
#
#     Store a message in a variable, and then print that message.
#     Store a new message in the same variable, and then print that new message.
#
# ###### First Name Cases
#
#     Store your first name, in lowercase, in a variable.
#     Using that one variable, print your name in lowercase, Titlecase, and UPPERCASE.
#
# ###### About This Person
#
#     Choose a person you look up to. Store their first and last names in separate variables.
#     Use concatenation to make a sentence about this person, and store that sentence in a variable.-
#     Print the sentence.
#
# ###### Name Strip
#
#     Store your first name in a variable, but include at least two kinds of whitespace on each side of your name.
#     Print your name as it is stored.
#     Print your name with whitespace stripped from the left side, then from the right side, then from both sides.

# %%
#Ex1
msg  = 'Hello Rock'
print (msg)
# Out:
# Hello Rock

# %%
#Ex2
msg = 'Hello ROCK'
print (msg)
msg = 'Hello Rocky'
print (msg)
# Out:
# Hello ROCK
# Hello Rocky

# %%
#Ex3
fname = 'Rocky Balboa'
print (fname)
print (fname.upper())
print(fname.capitalize())
# Out:
# Rocky Balboa
# ROCKY BALBOA
# Rocky balboa

# %%
#Ex4s
fname = 'Rocky'
lname = 'Balboa'
fullname = fname.capitalize() + ' ' + lname.capitalize() + ' is the best Boxer.';
print (fullname)
# Out:
# Rocky Balboa is the best Boxer.

# %%
#Ex5 
fname = '  Richie ' + ' ' + ' Rich'
fname = ' Richie    Richard   Rich '
print (fname)
print (fname.lstrip(' '))
print (fname.rstrip(' '))
print (fname.strip(' '))
# Out:
#  Richie    Richard   Rich
# Richie    Richard   Rich
#  Richie    Richard   Rich
# Richie    Richard   Rich
