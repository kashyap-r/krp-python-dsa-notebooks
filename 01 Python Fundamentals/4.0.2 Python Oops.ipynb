# %% [markdown]
# ### Initializing Class Instances
#
# ![image.png](attachment:bf25912d-a026-432c-ba7a-3e47c26e49dd.png)
#
#
# **If there is a "self" or anything that denotes or behaves like it in there, it means that it is a method belonging to a class**

# %%
class MyClass:
    language = 'Python'

    def __init__(obj, version):
        obj.version = version
