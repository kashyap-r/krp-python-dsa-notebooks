# %% [markdown]
# Suppressing Warnings in Python `

# %%
Using the warnings Module
You can use Python’s built-in warnings module to suppress warnings:

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Using IPython Magic Commands
# You can also use IPython magic commands to suppress warnings for a specific cell:
