# %% [markdown]
# 1. When looping through a sequence, the position index and corresponding value can be retrieved at the
# same time using the **enumerate() function.**

# %%
for i, v in enumerate(['K', 'A', 'S', 'H', 'Y', 'A', 'P']):
    print (i, v)
# Out:
# 0 K
# 1 A
# 2 S
# 3 H
# 4 Y
# 5 A
# 6 P

# %% [markdown]
# 2. To loop over two or more sequences at the same time, the entries can be paired with the **zip() function.**

# %%
q = ['name', 'quest', 'favcolor']
ans = ['Tom', 'the holy grail', 'Blue']
for q, a in zip(q, ans):
    print ('What is your {0} ? It is {1}.'.format(q, a))
# Out:
# What is your name ? It is Tom.
# What is your quest ? It is the holy grail.
# What is your favcolor ? It is Blue.

# %% [markdown]
# 3. To loop over a sequence in reverse, first specify the sequence in a forward direction and then call the **reversed() function**

# %%
for i in reversed(range(1, 10, 2)):
    print (i)
# Out:
# 9
# 7
# 5
# 3
# 1

# %% [markdown]
# To loop over a sequence in sorted order, use the **sorted() function** which returns a new sorted list while leaving the source unaltered

# %%
basket = ['apple', 'guava', 'orange', 'pear', 'banana']
for f in sorted(set(basket)):
    print (f)
# Out:
# apple
# banana
# guava
# orange
# pear

# %% [markdown]
# When looping through dictionaries, the key and corresponding value can be retrieved at the same time using the **iteritems() method.**

# %%
knights = {'gallahad': 'the pure', 'robin': 'the brave'}
for k, v in knights.iteritems():
    print (k, v)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 knights = {'gallahad': 'the pure', 'robin': 'the brave'}
# ----> 2 for k, v in knights.iteritems():
#       3     print (k, v)
#
# AttributeError: 'dict' object has no attribute 'iteritems'

# %% [markdown]
# It is sometimes tempting to change a list while you are looping over it; however, it is often simpler and safer to create a new list instead.

# %%
import math
raw_data = [56.2, float('NaN'), 51.7, 55.3, 52.5, float('NaN'), 47.8]
filtered_data = []
for value in raw_data:
    if not math.isnan(value):
        filtered_data.append(value)

filtered_data
# Out:
# [56.2, 51.7, 55.3, 52.5, 47.8]
