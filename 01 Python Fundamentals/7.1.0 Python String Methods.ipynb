# %%
# To change the case 

str1 = 'Kashyap'
str2 = 'RAJ'
str3 = 'purohit'

print (str1.lower())
print (str3.upper())
print (str3.title())
print (str2.swapcase())
print (str3.capitalize())
# Out:
# kashyap
# PUROHIT
# Purohit
# raj
# Purohit

# %% [markdown]
# Time complexity: O(n) where n is the length of the string ‘text’
# Auxiliary space: O(1)

# %%
#  pad the string with specified character 
str1 = 'kashyap'

print (str1.center(16))
print (str1.center(16, '#'))
print (str1.count('a'))
# Out:
#     kashyap
# ####kashyap#####
# 2

# %% [markdown]
# ## Python String join() Method
# used to join elements of a sequence separated by a string separator. This function joins elements of a sequence and makes it a string.
#
# Syntax: separator_string.join(iterable)
#
# Parameters:
#
# Iterable – objects capable of returning their members one at a time. Some examples are List, Tuple, String, Dictionary, and Set
# Return Value: The join() method returns a string concatenated with the elements of iterable.
#
# Type Error: If the iterable contains any non-string values, it raises a TypeError exception.

# %%
str = '-'.join('Hello')
str
# Out:
# 'H-e-l-l-o'

# %%
#  joining a list into a string 
list = ['k', 'a', 's', 'h', 'u']
print ("".join(list))

# joining with a string 
print ("$".join("   Kashyap   "))
# Out:
# kashu
#  $ $ $K$a$s$h$y$a$p$ $ $

# %%
# joining tuple with a string 

tuple = ('1', '2', '3', '4', '5')
s = '-' 
print (s.join(tuple))
# Out:
# 1-2-3-4-5

# %%
# join sets element into a string 

set1 = {'1', '2', '3', '4', '5', '2'}

s= '-$-'

print (s.join(sorted(set1)))

#  Note the missing duplicate 2 in the output - this is a feature of a set
# Out:
# 1-$-2-$-3-$-4-$-5

# %%
#  join string with a dictionary 

dic = {'K': 1, 'A': 2, 'S': 3, 'H': 4}

print ("".join(dic))
# Out:
# KASH

# %%
dic = {1:'Geek', 2:'For', 3:'Geeks'}

# Joining special character with dictionary
string = '_'.join(dic)

print(string)

"""
Note: When we join the dictionary keys it only joins the keys which are string only not an integer let’s see this in the code.
"""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 4
#       1 dic = {1:'Geek', 2:'For', 3:'Geeks'}
#       3 # Joining special character with dictionary
# ----> 4 string = '_'.join(dic)
#       6 print(string)
#
# TypeError: sequence item 0: expected str instance, int found

# %%
#  join a list of string with a custom separator 

words = ['apple', 'falls', 'far', "", "from", "the", 'tree']

result = "@ ".join(word for word in words if word)
print (result)

result = "@ ".join(word for word in words)
print (result)
# Out:
# apple@ falls@ far@ from@ the@ tree
# apple@ falls@ far@ @ from@ the@ tree

# %%
# join non string elements
elements = [1, 2, 3]
result = '-'.join(elements)
print (results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 elements = [1, 2, 3]
# ----> 2 result = '-'.join(elements)
#       3 print (results)
#
# TypeError: sequence item 0: expected str instance, int found

# %%
# convert non-string elements before joim
elements = [1, 2, 3]
result = '-'.join(map(str, elements))
print (result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 # convert non-string elements before joim
#       2 elements = [1, 2, 3]
# ----> 3 result = '-'.join(map(str, elements))
#       4 print (result)
#
# TypeError: 'str' object is not callable

# %%
# join with space as spearator 
print (" ".join(['Hi,', 'this', 'is', 'kashyap']))
# Out:
# Hi, this is kashyap

# %% [markdown]
# Python String partition() method splits the string at the first occurrence of the separator and returns a tuple containing the part before the separator, the separator, and the part after the separator. Here, the separator is a string that is given as the argument.

# %%
str = "I love Geeks for geeks"
print(str.partition("for"))
# Out:
# ('I love Geeks ', 'for', ' geeks')

# %%
string = "light attracts bug"
# 'attracts' separator is found
print(string.partition('attracts'))

string = "gold is heavy"
# 'is' as partition
result = string.partition('is')
print(result)
type(result)
# Out:
# ('light ', 'attracts', ' bug')
# ('gold ', 'is', ' heavy')
# tuple

# %%
string = "b follows a, c follows b"
print(string.partition('follows'))

string = "I am happy, I am proud"
print(string.partition('am'))
# Out:
# ('b ', 'follows', ' a, c follows b')
# ('I ', 'am', ' happy, I am proud')

# %%
# Result of partition() Method when the separator is missing from the String
string = "geeks for geeks"
print(string.partition('are'))
# Out:
# ('geeks for geeks', '', '')

# %%
# Case sensitive Python

sentence = "The quick Brown fox jumps over the lazy Fox."
result = sentence.partition("fox")
print(result)
result = sentence.partition("Fox")
print(result)
# Out:
# ('The quick Brown ', 'fox', ' jumps over the lazy Fox.')
# ('The quick Brown fox jumps over the lazy ', 'Fox', '.')

# %% [markdown]
# The string replace() method returns a copy of the string where occurrences of a substring are replaced with another substring
#
# String replace() Method Syntax
# string.replace(old, new, count
#
# Parameters:
# old – old substring you want to replace.
# new – new substring which would replace the old substring.
# count – ( Optional ) the number of times you want to replace the old substring with the new substring.
# Return Value :
# It returns a copy of the string where all occurrences of a substring are replaced with another substring.)

# %%
string = "Hello World"
new_string = string.replace("Hello", "Good Bye")

print(new_string)
# Out:
# Good Bye World

# %%
# endswith()

# %%
# format()

# %%
# index

# %%
# isalnum()

# %%
# isalpha()

# %%
# isdecimal()

# %%
# isdigit()

# %%
# islower()

# %%
# isnumeric()

# %%
# isupper()

# %% [markdown]
# # find()
#
# Python String find() method returns the lowest index or first occurrence of the substring if it is found in a given string.
#
# Python String find() Method Syntax
# str_obj.find(sub, start, end)
#
# Parameters
# sub: Substring that needs to be searched in the given string.
# start (optional): Starting position where the substring needs to be checked within the string.
# end (optional): The end position is the index of the last value for the specified range. It is excluded while checking.
# Return
# Returns the lowest index of the substring if it is found in a given string. If it’s not found then it returns -1.

# %%
string = " hello world is the first code of every programmer, find the first first"
print(string.find("first"))
print(string.rfind("first"))
# Out:
# 20
# 67

# %%
word = 'geeks for geeks'

# returns first occurrence of Substring
result = word.find('geeks')
print("Substring 'geeks' found at index:", result)

result = word.find('for')
print("Substring 'for ' found at index:", result)

# How to use find()
if word.find('pawan') != -1:
    print("Contains given substring ")
else:
    print("Doesn't contains given substring")
# Out:
# Substring 'geeks' found at index: 0
# Substring 'for ' found at index: 6
# Doesn't contains given substring

# %%
# 2. find() With start and end Arguments

# %%
# lower()

# lstrip()

# rstrip()

# partition()

# replace()



# rindex()

# rjust()

# rpartition()

# rparition()

# rsplit()

# splitlines()

# startswith()

# strip()

# zfill()

# %% [markdown]
# ### rfind()
#
# Python String rfind() Method Syntax
# Syntax:  str.rfind(sub, start, end)
#
# Parameters:
#
# sub: It’s the substring that needs to be searched in the given string.
# start: Starting position where the sub needs to be checked within the string.
# end: Ending position where suffix needs to be checked within the string.
# Note: If start and end indexes are not provided then, by default it takes 0 and length-1 as starting and ending indexes where ending indexes are not included in our search.
#
# Return:  Returns the right-most index of the substring if it is found in the given string; if not found, then it returns -1

# %%
str = 'Kashyaphit Rajpurohit'
# start searching from the right 
print (str.rfind("hit"))

# start searching from the left
print (str.find("hit"))
# Out:
# 18
# 7

# %%
# Python program to demonstrate working of rfind()
# in a sub-string
word = 'geeks for geeks'
# Substring is searched in 'eeks for geeks'
print(word.rfind('ge', 2))
# Substring is searched in 'eeks for geeks' 
print(word.rfind('geeks', 2))
# Substring is searched in 'eeks for geeks' 
print(word.rfind('geeks ', 2))
# Substring is searched in 's for g'
print(word.rfind('for ', 4, 11))
# finding substring using -ve indexing
print(word.rfind('geeks', -5))
# Out:
# 10
# 10
# -1
# 6
# 10

# %%
# practical example of rfind 

email = 'userxyz.com@domain.xyz'
last_dot_pos = email.rfind('.', 1)
print (last_dot_pos)
tld_string = email[last_dot_pos:]
print (tld_string)

if tld_string == ".com":
    print("Email matched")
else:
    print("Email not matched, tld:", tld_string)
# Out:
# 18
# .xyz
# Email not matched, tld: .xyz
