# %%
#Fibonacci Series 
#the sum of two elements defines the next

a, b= 0, 1

while b < 10:
    print (b)
    a, b=b, a+b
# Out:
# 1
# 1
# 2
# 3
# 5
# 8

# %%
#Fibonacci Series - another algorithm

a, b = 0, 1

while b < 10:
    #print ('a=',a)
    print ('b=',b)
    b = a + b
    a = b
# Out:
# b= 1
# b= 1
# b= 2
# b= 4
# b= 8
