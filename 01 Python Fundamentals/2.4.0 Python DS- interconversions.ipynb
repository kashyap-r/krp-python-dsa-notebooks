# %%
https://www.geeksforgeeks.org/python-convert-list-of-string-to-list-of-list/?ref=rp

https://www.geeksforgeeks.org/python-convert-list-of-tuples-to-list-of-list/?ref=rp

https://www.geeksforgeeks.org/python-convert-list-of-string-list-to-string-list/?ref=rp

https://www.geeksforgeeks.org/python-program-to-find-the-total-sum-of-a-nested-list-using-recursion/?ref=rp

https://www.geeksforgeeks.org/python-program-to-convert-a-list-of-strings-with-a-delimiter-to-a-list-of-tuple/?ref=rp

https://www.geeksforgeeks.org/python-program-to-create-a-list-of-tuples-from-given-list-having-number-and-its-cube-in-each-tuple/?ref=rp

https://www.geeksforgeeks.org/python-program-to-find-the-total-sum-of-a-nested-list-using-recursion/?ref=rp

https://www.geeksforgeeks.org/python-program-to-find-tuples-with-positive-elements-in-list-of-tuples/?ref=rp

https://www.geeksforgeeks.org/python-program-to-find-tuples-which-have-all-elements-divisible-by-k-from-a-list-of-tuples/?ref=rp

https://www.geeksforgeeks.org/python-program-to-find-the-sum-of-all-even-and-odd-digits-of-an-integer-list/?ref=rp

https://www.geeksforgeeks.org/copy-python-deep-copy-shallow-copy/?ref=rp

# %%
# Program to sum the elements in list 
total = 0 
list1 = [10, 5, 20, 30, 40, 50]

# iterate each element in the list and add them 
for ele in range(0, len(list1)):
    total = total` + list1[ele]

print ("Sum of all elements = ", total)


# to sum the elements in list using while loop 
total = 0
ele = 0

list1 = [10, 20, 30, 40, 50]
while (ele < len(list1)):
    total += list1[ele]
    ele += 1
print ("Sum of all elements = ", total)


# recursive way 

list1 = [10, 20, 30, 40, 50]
def SumOfList(list, size):
    if (size ==0):
        return 0
    else:
        return list[size-1] + SumOfList(list, size -1 )
    
total = SumOfList(list1, len(list1))
print ("Sum of all elements = ", total)

# Using sum() method 

list1 = [10, 20, 30, 40, 50]
total = sum(list1)

print ("Sum of all elements = ", total)

import sys
list1 = [0] * 3
list2 = [0, 0, 0]
list3 = [0 for i in range(3)]

print (list1)
print (list2)
print (list3)
print (sys.getsizeof(list1))
print (sys.getsizeof(list2))
print (sys.getsizeof(list3))

# %% [markdown]
# ### Main article:
# https://www.geeksforgeeks.org/python-data-structures-and-algorithms/
#
# #### Below is from main article
#
#
# ## Lists
#     are ordered collections of data just like arrays in other programming languages. It allows different types of elements in the list.
#
# The costly operation is inserting or deleting the element from the beginning of the List as all the elements are needed to be shifted. Insertion and deletion at the end of the list can also become costly in the case where the preallocated memory becomes full.

# %%
List = [1, 2, 3, "GFG", 2.3]
print(List)

# %% [markdown]
# ### Accessing elements of the List
#
# List elements can be accessed by the assigned index. In python starting index of the list, a sequence is 0 and the ending index is (if N elements are there) N-1.
#
# ![image.png](attachment:image.png)

# %%
# Creating a List with
# the use of multiple values
List = ["Geeks", "For", "Geeks"]
print("\nList containing multiple values: ")
print(List)

# %%
# Creating a Multi-Dimensional List
# (By Nesting a list inside a List)
a = [[2, 4, 6, 8, 10], [3, 6, 9, 12, 15], [4, 8, 12, 16, 20]] 
for record in a: 
    print(record)

# %%
a = [[2, 4, 6, 8, 10], [3, 6, 9, 12, 15], [4, 8, 12, 16, 20]] 
for i in range(len(a)): 
    for j in range(len(a[i])):
        print (a[i][j], end="  ")
    print ()

# %%
# Adding a sublist 
  
a = [[2, 4, 6, 8, 10], [3, 6, 9, 12, 15], [4, 8, 12, 16, 20]] 
print (a)
a.append([5, 10, 15, 20, 25]) 
print(a)

# %%
# Extending a sublist  
  
a = [[2, 4, 6, 8, 10], [3, 6, 9, 12, 15], [4, 8, 12, 16, 20]] 
print (a)
a[0].extend([12, 14, 16, 18]) 
print(a)

# %%
# Reversing a sublist 
a = [[2, 4, 6, 8, 10], [3, 6, 9, 12, 15], [4, 8, 12, 16, 20]] 
print (a)
a.reverse() 
print(a) 
a[1].reverse()
print (a)

# %%
# accessing a element from the
# list using index number
print("Accessing element from the list")
print(List[0])
print(List[2])

# accessing a element using
# negative indexing
print("Accessing element using negative indexing")
	
# print the last element of list
print(List[-1])
	
# print the third last element of list
print(List[-3])
