# %%
https://www.techbeamers.com/python-multithreading-concepts/

# %%
http://www.blopig.com/blog/2016/08/processing-large-files-using-python/

# %%
https://www.geeksforgeeks.org/writing-files-background-python/?ref=rp

# %%
https://docs.python.org/3/library/threading.html
