# %%
Dataframes

# %%
https://www.geeksforgeeks.org/difference-between-shallow-copy-vs-deep-copy-in-pandas-dataframes/?ref=rp

# %%
https://www.geeksforgeeks.org/shallow-copy-vs-deep-copy-in-pandas-series/?ref=rp
