# %% [markdown]
# 49. Group Anagrams
#
# Given an array of strings strs, group the anagrams together. You can return the answer in any order.
#
# An anagram is a word or a phrase formed by rearranging the letters of a different word or a phrase, typically using all the original letters exactly once
#
# Example 1:
#
# Input: strs = ["eat","tea","tan","ate","nat","bat"]
#
# Output: [["bat"],["nat","tan"],["ate","eat","tea"]]
#
# Explanation:
#
#     There is no string in strs that can be rearranged to form "bat".
#     The strings "nat" and "tan" are anagrams as they can be rearranged to form each other.
#     The strings "ate", "eat", and "tea" are anagrams as they can be rearranged to form each other.
#
#
# My thoughts:
#
#
# Brute Force method:
#
#     1. Take each of the word and compare that with all the other words caharacter by character
#
#     2. Here the Time will be O(n^2)
#
# The make this better
#     1. What if we are abke to go through each word only once
#
#     2. So we can use hashmap (a dict   )
#
#     3. We will go through each word once and check if its combination of letters ois already in the hashmap

# %%
def groupAnagrams(lst):
    anaMap = {}
    result = []
    for word in lst:
        sorted_word = sorted(word)
        anaMap[sorted_word].append(word)
        # will fail because we have not initialized the key in the anaMap

# %%
from collections import defaultdict 

def groupAnagrams(strs):
    # for each keyin the dict the deafult value will be an empty list
    anaMap = defaultdict(list)
    result= []

    for word in strs:
        sorted_w = tuple(sorted(word))
        anaMap[sorted_w].append(word)

    for val in anaMap.values():
        result.append(val)
    return result

strs = ["eat","tea","tan","ate","nat","bat"]
print (groupAnagrams(strs))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
# My Submitted solution 

class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        anagrams = defaultdict(list)
        for s in strs:
            # Sort the string and use it as a key
            sorted_str = ''.join(sorted(s))
            anagrams[sorted_str].append(s)
        
        return list(anagrams.values())
