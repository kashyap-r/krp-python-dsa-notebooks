# %% [markdown]
# 515. Find Largest Value in Each Tree Row
#
# Given the root of a binary tree, return an array of the largest value in each row of the tree (0-indexed).

# %%
from collections import deque 

class Node: 
    def __init__(self, x):
        self.val = x 
        self.left = None 
        self.right = None 

def largestValues(root):
    if root is None:
        return [] 
    
    result = []
    visitedNodes = []
    queue = deque([root])

    while queue:
        levelSize = len(queue)
        levelNodes = []
        for _ in range(levelSize):
            node = queue.popleft()
            levelNodes.append(node.val)            

            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)
            
        result.append(max(levelNodes))
        visitedNodes.append(levelNodes)
    return result, visitedNodes

root = Node(1) 
root.left = Node(3)
root.right = Node(2)
root.right.right = Node(9)
root.left.left = Node(5)
root.left.right = Node(3)

result, visitedNodes = largestValues(root)

print (result)
print (visitedNodes)
# Out:
# [1, 3, 9]
# [[1], [3, 2], [5, 3, 9]]

# %%
from collections import deque 

class Node: 
    def __init__(self, x):
        self.val = x 
        self.left = None 
        self.right = None 

def largestValues(root):
    if root is None:
        return []     
    result = []    
    queue = deque([root])
    while queue:
        levelSize = len(queue)
        levelNodes = []
        for _ in range(levelSize):
            node = queue.popleft()
            levelNodes.append(node.val)            
            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)            
        result.append(max(levelNodes))        
    return result

root = Node(1) 
root.left = Node(3)
root.right = Node(2)
root.right.right = Node(9)
root.left.left = Node(5)
root.left.right = Node(3)

result = largestValues(root)
print (result)
# Out:
# [1, 3, 9]
