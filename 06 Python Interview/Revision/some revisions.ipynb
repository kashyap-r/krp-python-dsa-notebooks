# %%
# Lists 
a = [1, 2, 3, 4]

b = 'kashyap'
print (b)
b = list(b)
print (b)

# create list with repeated elements 
c = [2]*5
d = ['Ka'] * 10
print(c) 
print (d)
print ()
x = 'Kashyap'
print (x[0])
print (x[3:])
print (x[:3])
print (x[2:4])
print (x[:-1])
print (x[::-1])

y = list(x)
print (y[0])
print (y[3:])
print (y[:3])
print (y[2:4])
print (y[:-1])
print (y[::-1])
# Out:
# kashyap
# ['k', 'a', 's', 'h', 'y', 'a', 'p']
# [2, 2, 2, 2, 2]
# ['Ka', 'Ka', 'Ka', 'Ka', 'Ka', 'Ka', 'Ka', 'Ka', 'Ka', 'Ka']
#
# K
# hyap
# Kas
# sh
# Kashya
# payhsaK
# K
# ['h', 'y', 'a', 'p']
# ['K', 'a', 's']
# ['s', 'h']
# ['K', 'a', 's', 'h', 'y', 'a']
# ['p', 'a', 'y', 'h', 's', 'a', 'K']
