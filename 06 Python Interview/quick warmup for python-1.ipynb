# %%
print (f"Hello Python");
# Out:
# Hello Python

# %%
# Variable declarations 

x = 5 
y = 3.14 
z = "Hi"
s1 = ["h", "i"]

print (x)
print(y)
print (type(z), z)
print (type(s1), s1)

# Multiple Assignments 
a = b = c = 100 
print (a, b, c)
# Out:
# 5
# 3.14
# <class 'str'> Hi
# <class 'list'> ['h', 'i']
# 100 100 100

# %%
# Global Variables
m = 10 

def my_function():
    # local variable 
    n = 5 
    print ("Local Variable y:", m)
    print ("Global Variable x:", n)

my_function()
print ("Local Variable y:", m)
# the variable n is not accessible here, so the below statement errors out
# print ("Global Variable x:", n)
# Out:
# Local Variable y: 10
# Global Variable x: 5
# Local Variable y: 10

# %% [markdown]
# ### Data types in Python
#
# int: integer
# float: foalting point numbers
# str: string
# bool: boolean
# list: a collection of ordered, mutable items (can store diffent datatypes)
# tuple: A collection of ordered, immutable items (cannot be changed after creation)
# set: a collection of unordered unique items
# dict: a collection of key, value pairs

# %%
# Typecasting in Python 

s = "10"
n = int(s)

count = 5
f = float(count)

age = 21
s2 = str(age)

print (type(s))
print (type(n))

print (type(count))
print (type(f))

print (type(age))
print (type(s2))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %%
# Taking input 
name = input("Enter your name:")
print ("Hello", name)
# Out:
# Hello Kash

# %%
# Operators
# Variables 
a = 13 
b = 3

# Addition 
print ("Sum: ",a+b)

# Substraction 
print ("Subtracton: ", a-b)

# Multiplication 
print ("Product :", a*b)

# Division 
print("Division: ", a/b)

# Floor Division 
print ("Floor Division: ", a//b)

# Modulus 
print ("Reminder(modulus): ", a%b)

# Exponentiation 
print ("Exponential : ", a**b)
# Out:
# Sum:  16
# Subtracton:  10
# Product : 39
# Division:  4.333333333333333
# Floor Division:  4
# Reminder(modulus):  1
# Exponential :  2197

# %%
# Comparison Operators

a = 13 
b = 31 

# Equals to ==
print (a == b)

# Not equal to != 
print(a != b)

# Greater than 
print (a>b)

# Less than
print (a<b) 

# Greater than or equal to 
print (a>=b)

# Less than or equal to 
print (a<=b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
# Logical Operators
a = True 
b = False 

x = 1 
y = 0 

print (f"a = {a}, b = {b}")
print (f"x = {x}, y = {y}")
# Logical AND 
print (f"a and b: {a and b}")

print (f"x and y: {x and y}")

# Logical OR 
print (f"a or b: {a or b}")

print (f"x or y: {x or y}")

# Logical NOT
print (f"not a: {not a}")
# Out:
# a = True, b = False
# x = 1, y = 0
# a and b: False
# x and y: 0
# a or b: True
# x or y: 1
# not a: False

# %% [markdown]
# ### Assignment Operators
#
# = Assigns a value to a variable
#
# += Adds the right operand to the left and assign the result to the left
#
# -= Subtracts the right operand from the left operand and assigns the result to the left
#
# *= Multiplies the left operand by the right operand and assigns the result
#
# /=
#
# %=
#
# //=
#
# **==

# %%
a = 10 
b = a 
print (b) 

b += a 
print (b)

b -= a 
print (b)

b *= a 
print (b) 

b <<= a 
print (b)
# Out:
# 10
# 20
# 10
# 100
# 102400

# %% [markdown]
# ### Bitwise Operators
#
# Bitwise operators are used to perform operations on binary representations of numbers. These operators work on bits (0s and 1s) and perform bit-level operations.
#
#     Bitwise AND (&): Compares corresponding bits and returns 1 if both bits are 1, otherwise 0.
#     Bitwise OR (|): Compares corresponding bits and returns 1 if at least one of the bits is 1.
#     Bitwise XOR (Exclusive OR) (^): Compares corresponding bits and returns 1 if the bits are different, otherwise 0.
#     Bitwise Left Shift (<<): Shifts the bits of the number to the left by the specified number of positions, adding 0s at the right.
#     Bitwise Right Shift (>>): Shifts the bits of the number to the right by the specified number of positions, discarding the rightmost bits.

# %%
a = 10
b = 4 

print (a & b)
print ( a | b)
print (~a)
print (a^b)
print ( a >> 2 )
print ( a << 2 )
# Out:
# 0
# 14
# -11
# 14
# 2
# 40

# %% [markdown]
# ### Membership Operators
#
# These operators test whether a value is a member of a sequence (list, tuple, string, etc.).
#
#     in : Returns True if a value is found in the sequence.
#     not in: Returns True if a value is not found in the sequence.

# %%
x = 12 
y = 20 
a = [10, 20, 30, 40]

if (x not in a):
    print ("x not in the list")
else:
    print ("X is present in the list")

if (y in a):
    print ("y is present in the given list ")
else:
    print ("y is NOT present in the given list")
# Out:
# x not in the array
# y is present in the given list

# %% [markdown]
# ### Identity Operators
#
# These operators compare the memory locations of two objects.
#
#     is : Returns True if two variables point to the same object.
#     is not : Returns True if two variables do not point to the same object.

# %%
a = 10
b = 20 
c = a 

print (a is not b)
print ( a is c)
# Out:
# True
# True

# %% [markdown]
# ### Control Statements
# 1. Conditional Statements
#
#     If Statement
#
#     If - Else Statement
#
#     Elif Statement

# %%
x = 15 

if x > 10: 
    print ("x is greater than 10")
elif x == 10:
    print ("x is equal to 10")
else:
    print ("x is less than 10")
# Out:
# x is greater than 10

# %% [markdown]
# ### Control Statements
# 2. Loops
#
#     for loop
#
#     while loop

# %%
# for loop 
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# while loop
x = 0 
while x < 5: 
    print (x)
    x += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Control Statements
# 3. Loop Control Statements
#
#     1. break: Exits the loop entirely when a certain condition is met
#
#     2. continue: Skips the current iteration and moves to the next iteration of the loop.
#
#     3. pass: A placeholder that does nothing. It is used when a statement is synctactically required but no action is needed

# %%
for i in range(10):
    # using pass 
    if i == 1:
        pass 

    # using continue 
    if i == 2:
        continue 

    # using break 
    if i == 5:
        break 

    print ("i = ", i)
# Out:
# i =  0
# i =  1
# i =  3
# i =  4

# %%
def func():
    ...

def func1():
    pass 

func() 

func1()

# %% [markdown]
# ### Functions
#
#
# ### Return Statement

# %%
# function: no parameters, no return statement
def fun():
    print ("fun() called!")

# function: with parameters, no return statement 
def printSum(a, b):
    print ("Sum = ", a + b)

# function: no parameters, with return statement 
def greet():
    return "Hello!"

# function: with parameters, with return statement
def getSum(a, b) -> int:
    return a + b 

fun()
printSum(3, 4)
print(greet())
print(getSum(5, 7))
# Out:
# fun() called!
# Sum =  7
# Hello!
# 12

# %% [markdown]
# ### Function Arguements
#
# 1. Default Arguements
#
# These are values assigned to parameters in case no arguement is passed during the function call.

# %%
def greet(name="Guest") -> None:
    print ("Hello", name)

greet()
greet("James Bond")
# Out:
# Hello Guest
# Hello James Bond

# %% [markdown]
# ### Function Arguements
#
# 2. Keyword Arguements
# These allow you to pass arguements by explicitly naming the parameter.

# %%
def personInfo(name, age):
    print(f"{name} is {age} years old.")

personInfo(age=45, name="James Bond")
# Out:
# James Bond is 45 years old.

# %% [markdown]
# ### Function Arguements
#
# 3. Variable-length Arguements
#
# These allow you to pass a variable number of arguements to a function.
# Use *args for non-keyword and **kwargs for keyword arguments. *args allows a function to accept any number of positional arguments as a tuple. **kwargs allows a function to accept any number of keyword arguments as a dictionary.
#
# #### Non-Keyword Arguments (*args)

# %%
def print_names(*names):
    for name in names:
        print(name)

print_names("James", "Avengers", "Charlie", "Bob")

def sum_numbers(*args):
    return (sum(args))

print (sum_numbers(1, 2, 3, 4, 5))
# Out:
# James
# Avengers
# Charlie
# Bob
# 15

# %% [markdown]
# #### Keyword Arguments (**kwargs)
#
# The **kwargs syntax allows a function to accept any number of named (keyword) arguments. Inside the function, these arguments are captured and stored in a dictionary.

# %%
def showProfile(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

showProfile(name="Alice", role="Developer")
# Out:
# name: Alice
# role: Developer

# %% [markdown]
# #### Using them together
#
# You can use standard arguments, *args, and **kwargs all in a single function definition. However, you must follow this specific order:
#
# 1. Standard positional arguments
#
# 2. *args
#
# 3. **kwargs

# %%
def master_function(standar_arg, *args, **kwargs):
    print (f"Standard arguements: {standar_arg}")
    print (f"Args: {args}")
    print (f"kwargs: {kwargs}")

master_function("Hello", 1, 2, 3, active=True, theme='dark')
# Out:
# Standard arguements: Hello
# Args: (1, 2, 3)
# kwargs: {'active': True, 'theme': 'dark'}

# %% [markdown]
# ### Lambda Functions

# %%
# lambda function for basic operation (square of a number)
square = lambda x: x ** 2 
print (square(25))

# lambda with condition (check if number is even or odd)
even_odd = lambda x: "Even" if x % 2 == 0 else "Odd"
print (even_odd(4))

# Lambda with LIst comprehension (transform a list to its squares)
numbers = [1, 2, 3, 4]
squared_numbers = [lambda x: x ** 2 for x in numbers]  # List of lambda functions
squared_list = [func(num) for func, num in zip(squared_numbers, numbers)]
print(squared_list)  

# Lambda with filter() (filter numbers greater than 2)
filtered = filter(lambda x: x> 2, numbers)
print (list(filtered))

# Lambda with map() (double each number in the list)
doubled = map(lambda x: x * 2, numbers)
print(list(doubled))  

# Lambda with reduce() (find the product of a list of numbers)
from functools import reduce
product = reduce(lambda x, y: x * y, numbers)
print(product)
# Out:
# 625
# Even
# [1, 4, 9, 16]
# [3, 4]
# [2, 4, 6, 8]
# 24

# %% [markdown]
# ### Recursion

# %% [markdown]
# ### Sets

# %%
s = {'a','b','c','c'}

print (s)

s1 = set(['aa', 'bb', 'cc', 'bb'])
print (s1)

s2 = set(['aa', 'bb', 'cc'])
print (s2)
# Out:
# {'a', 'b', 'c'}
# {'aa', 'cc', 'bb'}
# {'aa', 'cc', 'bb'}

# %% [markdown]
# ## Properties of Sets

# %%
# Adding an element to the set 
s = {'Kashyap', 'Raj'}

print (s)
s.add("Purohit")
print (s)
# Out:
# {'Raj', 'Kashyap'}
# {'Raj', 'Kashyap', 'Purohit'}

# %%
s = {'Kashyap', 'Raj'}
# print(s[1])
s[1] = 'Hello'
print (s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 s = {'Kashyap', 'Raj'}
#       2 # print(s[1])
# ----> 3 s[1] = 'Hello'
#       4 print (s)
#
# TypeError: 'set' object does not support item assignment

# %%
# Python Frozen Sets 
s = set (["a", "b", "c", "d"])

print (s)
s.add("z")
print (s)

fs = frozenset(["g", "e", "f"])
print ("\nFrozen Set")
print (fs)
fs.add('x')
print (fs)
# Out:
# {'b', 'd', 'c', 'a'}
# {'d', 'z', 'c', 'a', 'b'}
#
# Frozen Set
# frozenset({'f', 'g', 'e'})
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 11
#       9 print ("\nFrozen Set")
#      10 print (fs)
# ---> 11 fs.add('x')
#      12 print (fs)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
# Methods of Sets 
people = {"aaa", "bbb", "ccc"}
print ("People:", end=' ')
print (people)
people.add("eee")
print(people)
for i in range(1, 6):
    people.add(i)

print (people)
# Out:
# People: {'bbb', 'ccc', 'aaa'}
# {'eee', 'bbb', 'ccc', 'aaa'}
# {'eee', 1, 2, 3, 4, 'ccc', 5, 'aaa', 'bbb'}

# %%
# Union operation on Python Sets 

set1 = {"aaa", "bbb", "ccc"}
print(set1)
set2 = {'ddd', 'eee'}
print(set2)
set3 = {'fff', 'ggg'}
print(set3)

# Union using union function
bigset = set1.union(set2)
print (bigset)

# union using | operator
bigset2 = set1 | set3
print (bigset2)

bigset3 = set1 | set2 | set3 
print(bigset3)
# Out:
# {'bbb', 'ccc', 'aaa'}
# {'eee', 'ddd'}
# {'fff', 'ggg'}
# {'eee', 'ccc', 'bbb', 'ddd', 'aaa'}
# {'ccc', 'bbb', 'fff', 'ggg', 'aaa'}
# {'eee', 'ggg', 'ccc', 'bbb', 'fff', 'ddd', 'aaa'}

# %%
# Intersection Operation on Sets 

set1 = set()
set2 = set()

for i in range (5):
    set1.add(i)

for i in range (3, 8):
    set2.add(i)

print (set1)
print (set2)

# Intersection using intersection function
set3 = set1.intersection(set2)
print (set3)

# intersection using & operator
set4 = set1 & set2 
print (set4)
# Out:
# {0, 1, 2, 3, 4}
# {3, 4, 5, 6, 7}
# {3, 4}
# {3, 4}

# %%
# Find differences of sets
# 

set1 = set()
set2 = set()

for i in range(6):
    set1.add(i)

for i in range(5, 9):
    set2.add(i)

print (set1)
print (set2)

# Difference of two sets using difference() function 
set3 = s1.difference(set2)
print (set3)

# Difference of two sets using - operator 
set4 = set1 - set2
print (set4)

set5 = set2 - set1 
print (set5)
# Out:
# {0, 1, 2, 3, 4, 5}
# {8, 5, 6, 7}
# {'cc', 'bb', 'aa'}
# {0, 1, 2, 3, 4}
# {8, 6, 7}

# %%
# Clearing Python Sets 
set1 = {1, 2, 3, 4, 5}
print (set1)
set1.clear()
print (set1)
# Out:
# {1, 2, 3, 4, 5}
# set()

# %% [markdown]
# # Operations in Set 's', s1, s2
#
# key in s        : Containment check
# key not in s    : non-containment check
# s1 == s2        : s1 is equivalent to s2
# s1 != s2        : s1 is not equivalent to s2
# s1 <= s2        : s1 is subset of s2
# s1 < s2         : s1 is proper subset of s2
# s1 >= s2        : s1 is superset of s2
# s1 > s2         : s1 is proper superset is s2
# s1 | s2         : union of s1 and s2
# s1 & s2         : the intersection of s1 and s2
# s1 - s2         : the set of elements in s1 but not in s2
# s1 ^ s2         : the set of elements in precisely one of s1 or s2

# %% [markdown]
# ### List
#
# Can contain duplicate items
# Mutable: items can be modified, replaced, or removed
# Ordered: maintains the order in which items are added
# Index-based: items are accessed using their position (starting from 0)
# Can store mixed data types (integers, strings, booleans, even other lists)

# %%
# Creating the list 
# Using square brackets 

a = ['a', 'b', 'c']
b = [1, 2, 3]
print (a)
print(b)

# Using list() contructor
a1 = list((1, 2, 3, 4, 5))
print (a1)
a2 = list('kashyap')
print (a2)
a3 = list()
print (a3)

n1 = [2] * 5
n2 = ['a'] * 6
print (n1)
print (n2)
n3 = [9.99] * 5
print (n3)
# Out:
# ['a', 'b', 'c']
# [1, 2, 3]
# [1, 2, 3, 4, 5]
# ['k', 'a', 's', 'h', 'y', 'a', 'p']
# []
# [2, 2, 2, 2, 2]
# ['a', 'a', 'a', 'a', 'a', 'a']
# [9.99, 9.99, 9.99, 9.99, 9.99]

# %%
# Accessing list elements  
# insertion or deletion from the beginning of the list is costly, all the elements 
# from the beiginning of the list needs to be shifted
# 

l1 = [1, 2, 3, 'a', ' ', '%']
print (l1)

print (l1[5])
print (l1[1:4])
print (l1[-1])
print (l1[:-1])

print (l1[::-1])
print (l1[-3:])
# Out:
# [1, 2, 3, 'a', ' ', '%']
# %
# [2, 3, 'a']
# %
# [1, 2, 3, 'a', ' ']
# ['%', ' ', 'a', 3, 2, 1]
# ['a', ' ', '%']

# %%
# List methods 
# append(): adds an element to the end of the list
# extend(): adds multiple elements to the end of the list 
# insert(): adds and element at a specific position 
# clear(): removes all items 

# update the elements of te list 
a = [1, 2, 3, 4]
print (a) 
a[1] = 11
print (a)
# Out:
# [1, 2, 3, 4]
# [1, 11, 3, 4]

# %%
# Removing elements from the list 
# remove(): removes the first occurance of an element : what if there are mulitple 
# occurances and I want to remove all of them 
# pop(): removes the element at a specific index or the last element if no index is 
# specified
# del statement deltes an element at a specific index

a = [1, 2, 3, 4, 5]
print (a) 
a.remove(2)
print (a) 
val = a.pop(3)
print (a) 

del a[0]
print (a)
# Out:
# [1, 2, 3, 4, 5]
# [1, 3, 4, 5]
# [1, 3, 4]
# [3, 4]

# %%
# Iterating over the lists

# using lops 

basket = ['apple','banana','cherry', 'donki', 'elegant']

for item in basket:
    print (item)
# Out:
# apple
# banana
# cherry
# donki
# elegant

# %%
# Nested LIsts 

matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
print (matrix)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
# List comprehension 

squares = [x**2 for x in range (1, 6)]
print (squares)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# How Python Stores List Elements?
# In Python, a list doesn’t store actual values directly. Instead, it stores references (pointers) to objects in memory. This means numbers, strings and booleans are separate objects in memory and the list just keeps their addresses.
#
# That’s why modifying a mutable element (like another list or dictionary) can change the original object, while immutables remain unaffected.

# %% [markdown]
# ## Python Dictionary
#
# Python dictionary is a data structure that stores the value in key: value pairs. Values in a dictionary can be of any data type and can be duplicated, whereas keys can't be repeated and must be immutable.
#
# Keys are case sensitive which means same name but different cases of Key will be treated distinctly.
# Keys must be immutable which means keys can be strings, numbers or tuples but not lists.
# Duplicate keys are not allowed and any duplicate key will overwrite the previous value.
# Internally uses hashing. Hence, operations like search, insert, delete can be performed in Constant Time.
# From Python 3.7 Version onward, Python dictionary are Ordered.

# %%
## Dictionaries
d1 = {'Name': 'Kash', 1: [1, 2, 3, 4]}
print (d1)
print (d1.items())
print (d1.keys())
print (d1.values())

# Accessing values in a dict
print (d1['Name'])

print (d1.get(1))

d2 = {x: x**2 for x in [1, 2, 3, 4, 5]}
print (d2)
# Out:
# {'Name': 'Kash', 1: [1, 2, 3, 4]}
# dict_items([('Name', 'Kash'), (1, [1, 2, 3, 4])])
# dict_keys(['Name', 1])
# dict_values(['Kash', [1, 2, 3, 4]])
# Kash
# [1, 2, 3, 4]
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
https://www.geeksforgeeks.org/python/python-lists/

https://www.geeksforgeeks.org/python/python-dictionary-comprehension/

# %%
# Removing dictionary items 
# del
# pop()
# clear()
# popitem()

https://www.geeksforgeeks.org/python/python-data-structures/

# %%
# https://www.geeksforgeeks.org/python/python-dictionary/
# Iterating through a dictionary 
# Using keys() method, using values() method or both using a for loop 
#  

d = {1}

# %%
"""
15.M. 3Sum
Given an integer array nums, return all the triplets [nums[i], nums[j], nums[k]] 
such that i != j, i != k, and j != k, and nums[i] + nums[j] + nums[k] == 0.

Notice that the solution set must not contain duplicate triplets.

"""
# Using two pointer method
def find3Sum(arr):
    arr.sort()

    result = []

    for i in range(len(arr)-2):
        if i > 0 and arr[i] == nums[i-1]:
            continue
        # fix the first element, point the left pointer to the 2nd element
        left = i+1
        # second pointer top point to the last element
        right = len(arr)-1

        while left < right:
            total = arr[i] + arr[left] + arr[right]

            if total == 0:
                result.append([arr[i], arr[left], arr[right]])

                while left < right and arr[left] == arr[left+1]:
                    left+= 1 
                while left < right and arr[right] == arr[right-1]:
                    right -= 1
                left += 1
                right -= 1
            elif total < 0:
                left += 1
            else:
                right -= 1
    return result

if __name__ == "__main__":
    nums = [-1, 0, 1, 2, -1, -4]
    print (find3Sum(nums))
# Out:
# [[-1, -1, 2], [-1, 0, 1]]

# %%
# <!-- Using hashmap -->

def threeSum(nums):
    result = set()
    n = len(nums)

    for i in range(n):
        seen = {}
        for j in range(i + 1, n):
            complement = - (nums[i] + nums[j])
            if complement in seen:
                triplet = tuple(sorted([nums[i], nums[j], complement]))
                result.add(triplet)
            seen[nums[j]] = j

    return [list(triplet) for triplet in result]

if __name__ == "__main__":
    nums = [-1, 0, 1, 2, -1, -4]
    print (find3Sum(nums))

# %%
"""
217. Contains Duplicate
Given an integer array nums, return true if any value appears at least twice 
in the array, and return false if every element is distinct.

Input: nums = [1,2,3,1]
Output: true
Explanation:
The element 1 occurs at the indices 0 and 3.
"""

def containsDup(arr):
    seen = set()
    for i in arr:
        print (i)
        if i in seen:
            return True
        seen.add(i)
    return False


if __name__ == "__main__":
    arr = [1, 2, 3, 2, 4, 5, 6, 7, 8]
    print (containsDup(arr))
# Out:
# 1
# 2
# 3
# 2
# True

# %%
"""
1.Easy. Two Sum
Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
You may assume that each input would have exactly one solution, and you may not use the same element twice.
You can return the answer in any order.

Example 1:
Input: nums = [2,7,11,15], target = 9
Output: [0,1]
Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].

Example 2:
Input: nums = [3,2,4], target = 6
Output: [1,2]

Example 3:
Input: nums = [3,3], target = 6
Output: [0,1]

"""

nums = [2,7,11,15]
target = 9
n = len(nums)
nmap = {}

for i in range(len(nums)):
    compliment = target - nums[i] 
    if compliment in nmap: 
        print (i, nmap[compliment])
        break
    nmap[nums[i]] = i
# Out:
# 1 0

# %%
"""
121. Best Time to Buy and Sell Stock

You are given an array prices where prices[i] is the price of a given stock on the ith day.

You want to maximize your profit by choosing a single day to buy one stock and choosing a different day in the future to sell that stock.

Return the maximum profit you can achieve from this transaction. If you cannot achieve any profit, return 0.

"""

class Solution:
    def maxProfit(self, prices) -> int:
        left, right = 0, 1
        maxProfit = 0 
        while right != len(prices):
            if prices[left] < prices[right]:
                profit = prices[right] - prices[left]
                maxProfit = max(maxProfit, profit)
            else:
                left = right 
            right += 1
        print (left, right)
        return maxProfit
    
soln = Solution()

prices = [7,1,5,3,6,4]
print (len(prices))
print (soln.maxProfit(prices))
# Out:
# 6
# 1 6
# 5

# %%
"""
88.Easy. Merge Sorted Array

You are given two integer arrays nums1 and nums2, sorted in non-decreasing order, and two integers m and n,
representing the number of elements in nums1 and nums2 respectively.
Merge nums1 and nums2 into a single array sorted in non-decreasing order.

The final sorted array should not be returned by the function, but instead be 
stored inside the array nums1. To accommodate this, nums1 has a length of m + n, where the first m elements denote the elements that should be merged,
and the last n elements are set to 0 and should be ignored. nums2 has a length 
of n.

Example 1:

Input: nums1 = [1,2,3,0,0,0], m = 3, nums2 = [2,5,6], n = 3

Output: [1,2,2,3,5,6]
Explanation: The arrays we are merging are [1,2,3] and [2,5,6].
The result of the merge is [1,2,2,3,5,6] with the underlined elements coming from nums1.


First check whether ..len(nums1) = m+n

Assumption is the len(nums1) can accomodate nums2 as well
"""

def mergearray(nums1, m, nums2, n):
    if len(nums1) < m + n:
        print ("Im here")
        return False
    idx = 0 
    for i in range(len(nums1)):
        if nums1[i] == 0 and idx < len(nums2):
            nums1[i] = nums2[idx]
            idx += 1
    n = len(nums1)
    for i in range(n):
        for j in range(i+1, n):
            if nums1[i] > nums1[j]:
                nums1[i], nums1[j] = nums1[j], nums1[i]

if __name__ == "__main__":

    nums1 = [1,2,3,0,0]
    m = 3
    nums2 = [2,5,6]
    n = 3
    print (len(nums1))
    mergearray(nums1, m, nums2, n)
    print (nums1)
# Out:
# 5
# Im here
# [1, 2, 3, 0, 0]

# %%
nums1 = [1, 2, 3, 0, 0, 0]
zero_count = nums1.count(0)
print (zero_count)
# Out:
# 3

# %%
"""
66.Easy. Plus One

You are given a large integer represented as an integer array digits, 
where each digits[i] is the ith digit of the integer. The digits are ordered
from most significant to least significant in left-to-right order. 

The large integer does not contain any leading 0's.

Increment the large integer by one and return the resulting array of digits.

Example 1:

Input: digits = [1,2,3]
Output: [1,2,4]
Explanation: The array represents the integer 123.
Incrementing by one gives 123 + 1 = 124.
Thus, the result should be [1,2,4].

Example 2:

Input: digits = [4,3,2,1]
Output: [4,3,2,2]
Explanation: The array represents the integer 4321.
Incrementing by one gives 4321 + 1 = 4322.
Thus, the result should be [4,3,2,2].

Example 3:

Input: digits = [9]
Output: [1,0]
Explanation: The array represents the integer 9.
Incrementing by one gives 9 + 1 = 10.
Thus, the result should be [1,0].

"""

# %%
l1 = [1, 2, 3]

# %%
# Singly LInked List 

class Node:
    def __init__ (self, data = None):
        self.data = data 
        self.next = None 


sll1 = Node(2)
o
