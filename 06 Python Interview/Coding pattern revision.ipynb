# %% [markdown]
# How to prepare fully (checklist)
#
# Python snippets you can paste from memory:
#
# frequency map (Counter), two-pointers template, sliding window template, heap pattern, binary search, interval merge.
#
# I/O: practice single-line list input (list(map(int, input().split()))), multi-line cases, and exact output format.
#
# Testing: for each pattern, keep one tiny example in your head you can dry-run in seconds.
#
# Time control: If 2 questions appear, spend ≤12 min on Q1; if AC (accepted) early, move to Q2; if not, ship the most correct version you have and proceed.
#
# Edge cases: empty input, duplicates, negatives, off-by-one, ties.

# %% [markdown]
# 25 hands-on practice tasks (mix of quick & medium)
#
# Focus on writing a clean solve() quickly.
#
# **Arrays / Strings / Hashing**
#
# 1) Return the most frequent element; tie-break by smallest value.
#
# 2) First unique character index in a string (or -1).
#
# 3) Product of array except self (no division).
#
# 4) Move zeros to end (stable).
#
# 5) Rotate array right by k in-place.
#
# 6) Longest repeating character replacement with at most K changes.
#
# 7) Check permutation: is s2 a permutation substring of s1 (window+count)?
#
# 8) Min window substring containing all chars of t.
#
# 9) String compression (run-length) and decompression.
#
# 10) Custom sort string given priority order.
#
# Greedy / Two-Pointers / Sorting
# 11) Non-overlapping intervals: erase min intervals to remove overlaps.
# 12) Meeting rooms: min # rooms for start/end times (sweep line).
# 13) Assign cookies (greedy match).
# 14) 3Sum (unique triplets).
# 15) Boats to save people (two-pointers).
#
# Heaps / Maps
# 16) Reorganize string so no adjacent equal chars (max-heap).
# 17) K closest points to origin.
# 18) Task scheduler with cooldown n.
#
# Graphs / BFS-lite (only if you’re comfortable)
# 19) Number of islands in a grid (BFS/DFS).
# 20) Shortest path in unweighted grid (BFS) from S to T avoiding obstacles.
#
# Math / Parsing
# 21) Add binary strings.
# 22) Evaluate RPN expression.
# 23) Simplify path (/a/./b/../../c/).
#
# Implementation / Ad-hoc
# 24) CSV parser with quotes/commas edge cases (minimal, if needed).
# 25) Version compare (“1.0.7” vs “1.0.10”).
