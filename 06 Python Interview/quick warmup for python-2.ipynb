# %% [markdown]
# ### String Manipulation

# %%
s1 = "Learning Python"

s2 = "Learning TypeScript"

print (s1) 
print (s2)

print (s1[10])
print(s2[-1])
# Out:
# Learning Python
# Learning TypeScript
# y
# t

# %%
# String slicing 
s1 = "Learning Python"
print (s1[1:4])
print (s1[2:])
print (s1[:4])
# print (s1[::-1])

s = s1 + 'T'
print (s)
# Out:
# ear
# arning Python
# Lear
# Learning PythonTT

# %%
# String Methods 

s1 = "  Learning Python.  "

print (f"The String: {s1}")
print (f"Length of the string: {len(s1)}")
print (f"String in Upper case: {s1.upper()}")
print (f"string in Lowercase: {s1.lower()}")
print (f"{s1.strip()}")
s1 = s1.replace("Python", "TypeScript")
print (s1)
# Out:
# The String:   Learning Python.
# Length of the string: 20
# String in Upper case:   LEARNING PYTHON.
# string in Lowercase:   learning python.
# Learning Python.
#   Learning TypeScript.

# %%
# Formatting String using f-strings or format() method.

# %% [markdown]
# Object-Oriented Programming
#
# Class: Blueprint for creating objects, defining attributes and behaviours
#
# Object: Instance of a class containing specific data and methods
#
# Inheritance: Mechanism where one class inherits attributes and methods from another
#
# Envapsulation: Hiding internal state and requiring all interaction through methods
#
# Polymorphism: Ability fo use methods in different ways (method overloading or pverriding)
#
# Abstraction: Hiding complex implmentationdetails and showing only essential features

# %%
class Animal:
    # constructor : initializes the object with attributes
    def __init__ (self, name, species):
        self.name = name 
        self.species = species

    # method: function inside a class
    def speak(self):
        print(f"{self.name} makes a sound!")

# inheritance
class Dog(Animal):
    def __init__(self, name, breed):
        super().__init__(name, "Dog") # calls the constructor of Animal class
        self.breed = breed

    # method overriding: overriding speak method of the animal class 
    def speak(self):
        print (f"{self.name}, a {self.breed}, barks!")

# encapsulation: hiding the internal state (age) of the class
class Person:
    def __init__(self, name, age):
        self.name = name 
        self.__age = age # private variable, cannot be accessed directly 

    # Getter method to access private attribute __age
    def get_age(self):
        return self.__age

    # Setter method to modify private attribute __age
    def set_age(self, age):
        if age > 0:
            self.__age = age 
        else:
            print("Invalid age!")

# Polymorphism: Using the method name for different behaviour 
class Cat(Animal):
    def __init__(self,name):
        super().__init__(name,"Cat") # Calls the constructor of Animal class with 'Cat' as species

# %%
class Dog:
    species = "Canine"

    def __init__(self, name, age):
        self.name = name 
        self.age = age 

# creating object of the class 
dog1 = Dog("Buddy", 4)
print (dog1.name)
print (dog1.species)
print (dog1.age)
# Out:
# Buddy
# Canine
# 4

# %%
# Inheritance 
class Animal:
    def __init__(self, name):
        self.name = name 

    def info(self):
        print("Animal Name:", self.name)

class Dog(Animal):
    def sound(self):
        print(self.name, "barks")

d = Dog("Milo")
d.info()
d.sound()
# Out:
# Animal Name: Milo
# Milo barks
